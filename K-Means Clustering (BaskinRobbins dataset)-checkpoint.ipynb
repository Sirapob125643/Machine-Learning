# %% [markdown]
# # Unsupervised Learning: K-Means Clustering
# (BaskinRobbins dataset)
#
# - Baskin Robbins nutritional information from http://www.baskinrobbins.ca/nutritional-information/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
print(f'pandas  version = {pd.__version__}')
print(f'numpy   version = {np.__version__}')
print(f'seaborn version = {sns.__version__}')
# Out:
# pandas  version = 1.4.4
# numpy   version = 1.21.5
# seaborn version = 0.12.0

# %%
df = pd.read_excel("BaskinRobbins.xlsx")
df.sample(10)
# Out:
#                           Flavour  Calories  Total Fat (g)  Trans Fat (g)  \
# 4                  Chocolate Chip       150             10            0.3
# 6       Chocolate Mousse \nRoyale       180             11            0.3
# 10                    Mango Tango       140              6            0.2
# 1               Caramel Macchiato       170              9            0.3
# 5   Chocolate Chip \nCookie Dough       170              9            0.3
# 9                    Cotton Candy       150              7            0.3
# 2                Cherries Jubilee       140              7            0.2
# 0                Breakfast in Bed       160              7            0.2
# 8                Cookies 'n Cream       170             10            0.3
# 7                Citrus Twist Ice        60              0            0.0
#
#     Carbohydrates (g)  Sugars (g)  Protein (g)
# 4                  15          11            3
# 6                  18          13            3
# 10                 18          15            2
# 1                  18          15            3
# 5                  20          14            3
# 9                  18          11            3
# 2                  16          12            2
# 0                  22          17            2
# 8                  16          11            3
# 7                  15          11            0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Flavour            11 non-null     object
#  1   Calories           11 non-null     int64
#  2   Total Fat (g)      11 non-null     int64
#  3   Trans Fat (g)      11 non-null     float64
#  4   Carbohydrates (g)  11 non-null     int64
#  5   Sugars (g)         11 non-null     int64
#  6   Protein (g)        11 non-null     int64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 744.0+ bytes

# %%
df.columns
# Out:
# Index(['Flavour', 'Calories', 'Total Fat (g)', 'Trans Fat (g)',
#        'Carbohydrates (g)', 'Sugars (g)', 'Protein (g)'],
#       dtype='object')

# %%
cols=['Calories', 'Total Fat (g)', 'Trans Fat (g)', 'Carbohydrates (g)', 'Sugars (g)', 'Protein (g)']

# %%
sns.pairplot(df, vars=cols, 
             plot_kws={'alpha': .4});

# %% [markdown]
# # Scikit-learn: KMeans Clustering

# %%
from sklearn import preprocessing
from sklearn.cluster import KMeans

# %%
df.columns
# Out:
# Index(['Flavour', 'Calories', 'Total Fat (g)', 'Trans Fat (g)',
#        'Carbohydrates (g)', 'Sugars (g)', 'Protein (g)'],
#       dtype='object')

# %%
cols=['Calories', 'Total Fat (g)', 'Trans Fat (g)', 'Carbohydrates (g)', 'Sugars (g)', 'Protein (g)']
## z-score
scaler = preprocessing.StandardScaler() # create StandardScaler instance
z=scaler.fit_transform(df[cols]) # calc z-score
z[:5].round(4) # 2D numpy array
# Out:
# array([[ 0.3814, -0.2243, -0.5103,  2.2054,  2.0531, -0.5103],
#        [ 0.7041,  0.4806,  0.6124,  0.2646,  1.0712,  0.6124],
#        [-0.264 , -0.2243, -0.5103, -0.7057, -0.4017, -0.5103],
#        [-0.264 ,  0.1282,  0.6124, -0.7057, -0.8926,  0.6124],
#        [ 0.0587,  0.8331,  0.6124, -1.1909, -0.8926,  0.6124]])

# %%
## Yeo-Johnson transformation (preferable)
pt = preprocessing.PowerTransformer(method='yeo-johnson', standardize=True) # support only positive value
mat = pt.fit_transform(df[cols])
mat[:5].round(4)
# Out:
# array([[ 0.2866, -0.4579, -1.1046,  1.7775,  1.5915, -1.0158],
#        [ 0.8948,  0.4613,  0.7406,  0.4645,  1.1544,  0.7279],
#        [-0.6636, -0.4579, -1.1046, -0.6657, -0.1795, -1.0158],
#        [-0.6636, -0.0204,  0.7406, -0.6657, -0.9914,  0.7279],
#        [-0.2298,  0.9863,  0.7406, -1.4362, -0.9914,  0.7279]])

# %%
bc_cols = [f'bc_{c}' for c in cols]
bc_cols
# Out:
# ['bc_Calories',
#  'bc_Total Fat (g)',
#  'bc_Trans Fat (g)',
#  'bc_Carbohydrates (g)',
#  'bc_Sugars (g)',
#  'bc_Protein (g)']

# %%
z_cols = [f'z_{c}' for c in cols]
z_cols
# Out:
# ['z_Calories',
#  'z_Total Fat (g)',
#  'z_Trans Fat (g)',
#  'z_Carbohydrates (g)',
#  'z_Sugars (g)',
#  'z_Protein (g)']

# %%
ds=pd.concat([df, pd.DataFrame(mat, columns=bc_cols), pd.DataFrame(z, columns=z_cols)], axis='columns')
ds.head()
# Out:
#              Flavour  Calories  Total Fat (g)  Trans Fat (g)  \
# 0   Breakfast in Bed       160              7            0.2
# 1  Caramel Macchiato       170              9            0.3
# 2   Cherries Jubilee       140              7            0.2
# 3          Chocolate       140              8            0.3
# 4     Chocolate Chip       150             10            0.3
#
#    Carbohydrates (g)  Sugars (g)  Protein (g)  bc_Calories  bc_Total Fat (g)  \
# 0                 22          17            2     0.286628         -0.457943
# 1                 18          15            3     0.894820          0.461253
# 2                 16          12            2    -0.663600         -0.457943
# 3                 16          11            3    -0.663600         -0.020381
# 4                 15          11            3    -0.229805          0.986324
#
#    bc_Trans Fat (g)  bc_Carbohydrates (g)  bc_Sugars (g)  bc_Protein (g)  \
# 0         -1.104568              1.777531       1.591548       -1.015750
# 1          0.740644              0.464494       1.154351        0.727935
# 2         -1.104568             -0.665694      -0.179480       -1.015750
# 3          0.740644             -0.665694      -0.991354        0.727935
# 4          0.740644             -1.436190      -0.991354        0.727935
#
#    z_Calories  z_Total Fat (g)  z_Trans Fat (g)  z_Carbohydrates (g)  \
# 0    0.381365        -0.224294        -0.510310             2.205405
# 1    0.704058         0.480631         0.612372             0.264649
# 2   -0.264022        -0.224294        -0.510310            -0.705730
# 3   -0.264022         0.128168         0.612372            -0.705730
# 4    0.058671         0.833094         0.612372            -1.190919
#
#    z_Sugars (g)  z_Protein (g)
# 0      2.053080      -0.510310
# 1      1.071172       0.612372
# 2     -0.401690      -0.510310
# 3     -0.892644       0.612372
# 4     -0.892644       0.612372

# %%
ds[cols].hist(layout=(1, len(cols)), figsize=(3*len(cols), 3.5));

# %%
ds[z_cols].hist(layout=(1, len(cols)), figsize=(3*len(cols), 3.5), color='green', alpha=.5);

# %%
ds[bc_cols].hist(layout=(1, len(cols)), figsize=(3*len(cols), 3.5), color='orange', alpha=.5);

# %%
X=pd.DataFrame(mat, columns=cols) ## power transformation (preferable)
# X=pd.DataFrame(z, columns=cols) ## z-score
X.head()
# Out:
#    Calories  Total Fat (g)  Trans Fat (g)  Carbohydrates (g)  Sugars (g)  \
# 0  0.286628      -0.457943      -1.104568           1.777531    1.591548
# 1  0.894820       0.461253       0.740644           0.464494    1.154351
# 2 -0.663600      -0.457943      -1.104568          -0.665694   -0.179480
# 3 -0.663600      -0.020381       0.740644          -0.665694   -0.991354
# 4 -0.229805       0.986324       0.740644          -1.436190   -0.991354
#
#    Protein (g)
# 0    -1.015750
# 1     0.727935
# 2    -1.015750
# 3     0.727935
# 4     0.727935

# %% [markdown]
# # scatter matrix with transformed data

# %%
sns.pairplot(X, 
             plot_kws={'alpha': .4});

# %% [markdown]
# # Scikit-learn: KMeans Clustering

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# # Optimal number of clusters

# %%
ssd=[]
for k in range(2, 10):
    m=KMeans(n_clusters=k)
    m.fit(X)
    ssd.append([k, m.inertia_])
ssd
# Out:
# [[2, 34.12581638170766],
#  [3, 22.876170974985822],
#  [4, 11.977572109947754],
#  [5, 8.066466759635986],
#  [6, 5.054333965711679],
#  [7, 3.5681307686383157],
#  [8, 2.105558816516895],
#  [9, 1.1763362521296683]]

# %%
xy=np.array(ssd)
print(xy)
# Out:
# [[ 2.         34.12581638]
#  [ 3.         22.87617097]
#  [ 4.         11.97757211]
#  [ 5.          8.06646676]
#  [ 6.          5.05433397]
#  [ 7.          3.56813077]
#  [ 8.          2.10555882]
#  [ 9.          1.17633625]]

# %%
plt.plot(xy[:, 0], xy[:, 1], linestyle='--', marker='o')
# plt.plot(xy[:, 0], xy[:, 1], '--o')

# %%
dd=pd.DataFrame(ssd, columns=['k', 'ssd'])
dd
# Out:
#    k        ssd
# 0  2  34.125816
# 1  3  22.876171
# 2  4  11.977572
# 3  5   8.066467
# 4  6   5.054334
# 5  7   3.568131
# 6  8   2.105559
# 7  9   1.176336

# %%
dd['pct_chg']=dd['ssd'].pct_change() * 100
dd
# Out:
#    k        ssd    pct_chg
# 0  2  34.125816        NaN
# 1  3  22.876171 -32.965205
# 2  4  11.977572 -47.641709
# 3  5   8.066467 -32.653574
# 4  6   5.054334 -37.341415
# 5  7   3.568131 -29.404531
# 6  8   2.105559 -40.989864
# 7  9   1.176336 -44.131874

# %%
plt.plot(dd['k'], dd['ssd'], linestyle='--', marker='o')
# plt.plot(xy[:, 0], xy[:, 1], '--o')
for index, row in dd.iterrows():
    plt.text(row['k']+.02, row['ssd']+.02, f'{row["pct_chg"]:.2f}', fontsize=10)

# %% [markdown]
# # fit the model

# %%
model = KMeans(n_clusters=3)
model
# X=df[cols]
# Out:
# KMeans(n_clusters=3)

# %%
model.fit(X)
# Out:
# KMeans(n_clusters=3)

# %%
model.cluster_centers_.round(4)
# Out:
# array([[-1.1507, -1.1711, -1.36  , -0.5458, -0.0055, -1.3599],
#        [ 0.9201,  0.5047,  0.2793,  0.9851,  0.9955,  0.292 ],
#        [-0.0571,  0.3736,  0.7406, -0.5758, -0.9914,  0.7279]])

# %%
model.transform(X) # the distance between each point and centroid
# Out:
# array([[3.27208881, 2.43653376, 4.41182955],
#        [4.24103372, 0.83764399, 2.56905342],
#        [0.98698885, 3.34156411, 2.85862717],
#        [3.36443659, 3.13997142, 0.72879161],
#        [4.00485654, 3.43035826, 1.07032826],
#        [4.41475102, 0.70275517, 2.74135881],
#        [4.99770889, 1.61053199, 2.67995303],
#        [2.12523921, 6.04339929, 5.11761004],
#        [4.31237569, 2.70334821, 1.1356436 ],
#        [3.48152552, 2.62114793, 1.34291129],
#        [1.69985971, 2.87525808, 3.74141515]])

# %%
model.labels_
# Out:
# array([1, 1, 0, 2, 2, 1, 1, 0, 2, 2, 0])

# %% [markdown]
# # sense making about each cluster

# %%
df['cluster']=model.labels_
df.head()
# Out:
#              Flavour  Calories  Total Fat (g)  Trans Fat (g)  \
# 0   Breakfast in Bed       160              7            0.2
# 1  Caramel Macchiato       170              9            0.3
# 2   Cherries Jubilee       140              7            0.2
# 3          Chocolate       140              8            0.3
# 4     Chocolate Chip       150             10            0.3
#
#    Carbohydrates (g)  Sugars (g)  Protein (g)  cluster
# 0                 22          17            2        1
# 1                 18          15            3        1
# 2                 16          12            2        0
# 3                 16          11            3        2
# 4                 15          11            3        2

# %%
df.groupby('cluster').describe().T
# Out:
# cluster                           0           1           2
# Calories          count    3.000000    4.000000    4.000000
#                   mean   113.333333  170.000000  152.500000
#                   std     46.188022    8.164966   12.583057
#                   min     60.000000  160.000000  140.000000
#                   25%    100.000000  167.500000  147.500000
#                   50%    140.000000  170.000000  150.000000
#                   75%    140.000000  172.500000  155.000000
#                   max    140.000000  180.000000  170.000000
# Total Fat (g)     count    3.000000    4.000000    4.000000
#                   mean     4.333333    9.000000    8.750000
#                   std      3.785939    1.632993    1.500000
#                   min      0.000000    7.000000    7.000000
#                   25%      3.000000    8.500000    7.750000
#                   50%      6.000000    9.000000    9.000000
#                   75%      6.500000    9.500000   10.000000
#                   max      7.000000   11.000000   10.000000
# Trans Fat (g)     count    3.000000    4.000000    4.000000
#                   mean     0.133333    0.275000    0.300000
#                   std      0.115470    0.050000    0.000000
#                   min      0.000000    0.200000    0.300000
#                   25%      0.100000    0.275000    0.300000
#                   50%      0.200000    0.300000    0.300000
#                   75%      0.200000    0.300000    0.300000
#                   max      0.200000    0.300000    0.300000
# Carbohydrates (g) count    3.000000    4.000000    4.000000
#                   mean    16.333333   19.500000   16.250000
#                   std      1.527525    1.914854    1.258306
#                   min     15.000000   18.000000   15.000000
#                   25%     15.500000   18.000000   15.750000
#                   50%     16.000000   19.000000   16.000000
#                   75%     17.000000   20.500000   16.500000
#                   max     18.000000   22.000000   18.000000
# Sugars (g)        count    3.000000    4.000000    4.000000
#                   mean    12.666667   14.750000   11.000000
#                   std      2.081666    1.707825    0.000000
#                   min     11.000000   13.000000   11.000000
#                   25%     11.500000   13.750000   11.000000
#                   50%     12.000000   14.500000   11.000000
#                   75%     13.500000   15.500000   11.000000
#                   max     15.000000   17.000000   11.000000
# Protein (g)       count    3.000000    4.000000    4.000000
#                   mean     1.333333    2.750000    3.000000
#                   std      1.154701    0.500000    0.000000
#                   min      0.000000    2.000000    3.000000
#                   25%      1.000000    2.750000    3.000000
#                   50%      2.000000    3.000000    3.000000
#                   75%      2.000000    3.000000    3.000000
#                   max      2.000000    3.000000    3.000000

# %%
sns.countplot(x='cluster', data=df);

# %%
df.columns
# Out:
# Index(['Flavour', 'Calories', 'Total Fat (g)', 'Trans Fat (g)',
#        'Carbohydrates (g)', 'Sugars (g)', 'Protein (g)', 'cluster'],
#       dtype='object')

# %%
cols=['Calories', 'Total Fat (g)', 'Trans Fat (g)', 'Carbohydrates (g)', 'Sugars (g)', 'Protein (g)']
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20, 9))
ax=ax.ravel()
for i, col in enumerate(cols):
    sns.violinplot(x='cluster', y=col, data=df, ax=ax[i])

# %%
cols=['Calories', 'Total Fat (g)', 'Trans Fat (g)', 'Carbohydrates (g)', 'Sugars (g)', 'Protein (g)']
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20, 9))
ax=ax.ravel()
for i, col in enumerate(cols):
    sns.boxenplot(x='cluster', y=col, data=df, ax=ax[i])

# %% [markdown]
# # raw data (no scaling)

# %%
sns.heatmap(df.groupby('cluster').median(), cmap='Oranges', linewidths=1);

# %%
dx=X
dx['cluster']=model.labels_
dx.head()
# Out:
#    Calories  Total Fat (g)  Trans Fat (g)  Carbohydrates (g)  Sugars (g)  \
# 0  0.286628      -0.457943      -1.104568           1.777531    1.591548
# 1  0.894820       0.461253       0.740644           0.464494    1.154351
# 2 -0.663600      -0.457943      -1.104568          -0.665694   -0.179480
# 3 -0.663600      -0.020381       0.740644          -0.665694   -0.991354
# 4 -0.229805       0.986324       0.740644          -1.436190   -0.991354
#
#    Protein (g)  cluster
# 0    -1.015750        1
# 1     0.727935        1
# 2    -1.015750        0
# 3     0.727935        2
# 4     0.727935        2

# %% [markdown]
# # scaled data (either z-score, power transform)

# %%
sns.heatmap(dx.groupby('cluster').median(), cmap="Blues", linewidths=1);

# %%
fig, ax = plt.subplots(ncols=2, figsize=(14, 4))
ax=ax.ravel()
sns.heatmap(df.groupby('cluster').median(), cmap="Oranges", linewidths=1, ax=ax[0]);
sns.heatmap(dx.groupby('cluster').median(), cmap="Blues", linewidths=1, ax=ax[1]);

# %%
cols=['Calories', 'Total Fat (g)', 'Trans Fat (g)', 'Carbohydrates (g)', 'Sugars (g)', 'Protein (g)', 'cluster']
fig, ax = plt.subplots(ncols=2, figsize=(18, 6))
ax=ax.ravel()
sns.heatmap(df[cols].groupby('cluster').median(), cmap="Oranges", linewidths=1, 
            square=True, annot=True, fmt='.2f',ax=ax[0]);
sns.heatmap(dx[cols].groupby('cluster').median(), cmap="Blues", linewidths=1, 
            square=True, annot=True, fmt='.2f', ax=ax[1]);

# %%
sns.pairplot(df, vars=['Calories', 'Total Fat (g)', 'Trans Fat (g)', 'Carbohydrates (g)', 'Sugars (g)', 'Protein (g)'], 
             hue='cluster',
             plot_kws={'alpha': .4});

# %%
df.groupby('cluster').head(3).sort_values('cluster')
# Out:
#                           Flavour  Calories  Total Fat (g)  Trans Fat (g)  \
# 2                Cherries Jubilee       140              7            0.2
# 7                Citrus Twist Ice        60              0            0.0
# 10                    Mango Tango       140              6            0.2
# 0                Breakfast in Bed       160              7            0.2
# 1               Caramel Macchiato       170              9            0.3
# 5   Chocolate Chip \nCookie Dough       170              9            0.3
# 3                       Chocolate       140              8            0.3
# 4                  Chocolate Chip       150             10            0.3
# 8                Cookies 'n Cream       170             10            0.3
#
#     Carbohydrates (g)  Sugars (g)  Protein (g)  cluster
# 2                  16          12            2        0
# 7                  15          11            0        0
# 10                 18          15            2        0
# 0                  22          17            2        1
# 1                  18          15            3        1
# 5                  20          14            3        1
# 3                  16          11            3        2
# 4                  15          11            3        2
# 8                  16          11            3        2
