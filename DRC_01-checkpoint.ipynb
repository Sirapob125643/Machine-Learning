# %% [markdown]
# ## Classification Tree

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %config InlineBackend.figure_format = 'svg'

# %%
print(f"pandas  version: {pd.__version__}")
print(f"numpy   version: {np.__version__}")
print(f"seaborn version: {sns.__version__}")
# Out:
# pandas  version: 1.4.4
# numpy   version: 1.21.5
# seaborn version: 0.12.0

# %%
df = pd.read_excel("Real_score_new1.xlsx")
df.sample(50)
# Out:
#       towerid  conductor_visual   Wi_con_vir  conductor_zinc   Wi_con_zin  \
# 207       208                 3           20               0           20
# 2577     2578                 3           20               0           20
# 4437     4438                 2           20               0           20
# 764       765                 3           20               0           20
# 3663     3664                 3           20               0           20
# 292       293                 3           20               0           20
# 2592     2593                 3           20               0           20
# 3452     3453                 2           20               0           20
# 3047     3048                 2           20               0           20
# 3611     3612                 1           20               0           20
# 1852     1853                 5           20               5           20
# 1757     1758                 5           20               5           20
# 4426     4427                 2           20               0           20
# 1209     1210                 3           20               0           20
# 1597     1598                 3           20               0           20
# 3236     3237                 4           20               0           20
# 4093     4094                 2           20               0           20
# 1071     1072                 3           20               0           20
# 4379     4380                 2           20               0           20
# 1694     1695                 5           20               5           20
# 1899     1900                 0           20               0           20
# 2581     2582                 3           20               0           20
# 200       201                 3           20               0           20
# 3800     3801                 2           20               0           20
# 2797     2798                 2           20               0           20
# 617       618                 2           20               0           20
# 4149     4150                 2           20               0           20
# 3952     3953                 3           20               0           20
# 533       534                 4           20               0           20
# 3652     3653                 3           20               0           20
# 4292     4293                 5           20               5           20
# 2264     2265                 3           20               0           20
# 4110     4111                 2           20               0           20
# 1940     1941                 4           20               0           20
# 1410     1411                 3           20               0           20
# 3065     3066                 3           20               0           20
# 3051     3052                 0           20               0           20
# 84         85                 3           20               0           20
# 4010     4011                 1           20               0           20
# 4256     4257                 4           20               0           20
# 2349     2350                 3           20               0           20
# 4006     4007                 3           20               0           20
# 111       112                 3           20               0           20
# 1594     1595                 3           20               0           20
# 1279     1280                 3           20               0           20
# 2756     2757                 3           20               0           20
# 2591     2592                 3           20               0           20
# 4043     4044                 3           20               0           20
# 816       817                 3           20               0           20
# 2333     2334                 3           20               0           20
#
#       conductor_tensile   Wi_con_ten  conductor_ductility   Wi_con_duc  \
# 207                   0           20                    0           20
# 2577                  0           20                    0           20
# 4437                  0           20                    0           20
# 764                   0           20                    0           20
# 3663                  0           20                    0           20
# 292                   0           20                    0           20
# 2592                  0           20                    0           20
# 3452                  0           20                    0           20
# 3047                  0           20                    0           20
# 3611                  0           20                    0           20
# 1852                  4           20                    0           20
# 1757                  4           20                    0           20
# 4426                  0           20                    0           20
# 1209                  0           20                    0           20
# 1597                  0           20                    0           20
# 3236                  0           20                    0           20
# 4093                  0           20                    0           20
# 1071                  0           20                    0           20
# 4379                  0           20                    0           20
# 1694                  4           20                    0           20
# 1899                  0           20                    0           20
# 2581                  0           20                    0           20
# 200                   0           20                    0           20
# 3800                  0           20                    0           20
# 2797                  0           20                    0           20
# 617                   0           20                    0           20
# 4149                  0           20                    0           20
# 3952                  0           20                    0           20
# 533                   0           20                    0           20
# 3652                  0           20                    0           20
# 4292                  4           20                    0           20
# 2264                  0           20                    0           20
# 4110                  0           20                    0           20
# 1940                  0           20                    0           20
# 1410                  0           20                    0           20
# 3065                  0           20                    0           20
# 3051                  0           20                    0           20
# 84                    0           20                    0           20
# 4010                  0           20                    0           20
# 4256                  0           20                    0           20
# 2349                  0           20                    0           20
# 4006                  0           20                    0           20
# 111                   0           20                    0           20
# 1594                  0           20                    0           20
# 1279                  0           20                    0           20
# 2756                  0           20                    0           20
# 2591                  0           20                    0           20
# 4043                  0           20                    0           20
# 816                   0           20                    0           20
# 2333                  0           20                    0           20
#
#       conductor_tensileaac  ...  %HImaxCon   %HImaxCA  %HImaxINS  %HImaxSS  \
# 207                      0  ...  20.000000   9.090909  50.000000         0
# 2577                     0  ...  20.000000  18.181818  75.000000         0
# 4437                     0  ...  20.000000  18.181818  50.000000         0
# 764                      0  ...  20.000000   9.090909  50.000000         0
# 3663                     0  ...  20.000000  18.181818  66.666667        50
# 292                      0  ...  20.000000   9.090909  50.000000         0
# 2592                     0  ...  20.000000  18.181818  75.000000         0
# 3452                     0  ...  20.000000  18.181818  50.000000         0
# 3047                     0  ...  20.000000  18.181818  70.000000        70
# 3611                     0  ...  20.000000   9.090909  50.000000        50
# 1852                     0  ...  56.000000  18.181818  70.000000        88
# 1757                     0  ...  56.000000  52.727273  85.000000        88
# 4426                     0  ...  20.000000  18.181818  50.000000         0
# 1209                     0  ...  20.000000   9.090909  50.000000         0
# 1597                     0  ...  20.000000   9.090909  50.000000        40
# 3236                     0  ...  20.000000  18.181818  70.000000        88
# 4093                     0  ...  20.000000   9.090909  50.000000        50
# 1071                     0  ...  20.000000   9.090909  50.000000         0
# 4379                     0  ...  20.000000  18.181818  75.000000         0
# 1694                     0  ...  56.000000  16.363636  65.000000        82
# 1899                     0  ...  56.000000  18.181818  70.000000        88
# 2581                     0  ...  20.000000  18.181818  75.000000         0
# 200                      0  ...  20.000000   9.090909  50.000000         0
# 3800                     0  ...  20.000000   9.090909  50.000000        50
# 2797                     0  ...  20.000000   9.090909  50.000000         0
# 617                      0  ...  20.000000   9.090909   0.000000         0
# 4149                     0  ...  20.000000   9.090909  50.000000        50
# 3952                     0  ...  20.000000   9.090909  75.000000        30
# 533                      0  ...  20.000000   9.090909  50.000000        40
# 3652                     0  ...  20.000000  18.181818  66.666667        50
# 4292                     0  ...  56.000000  52.727273  85.000000        88
# 2264                     0  ...  20.000000   9.090909  50.000000         0
# 4110                     0  ...  20.000000   9.090909  50.000000        50
# 1940                     0  ...  20.000000  52.727273  85.000000        88
# 1410                     0  ...  20.000000   9.090909  50.000000         0
# 3065                     0  ...  33.333333  30.303030  91.666667        60
# 3051                     0  ...  33.333333  30.303030  91.666667        60
# 84                       0  ...  20.000000   9.090909  50.000000         0
# 4010                     0  ...  20.000000   9.090909  75.000000        40
# 4256                     0  ...  56.000000  52.727273  85.000000        88
# 2349                     0  ...  20.000000   9.090909  50.000000         0
# 4006                     0  ...  20.000000   9.090909  75.000000        40
# 111                      0  ...  20.000000   9.090909  50.000000         0
# 1594                     0  ...  20.000000   9.090909  50.000000        40
# 1279                     0  ...  20.000000   9.090909  50.000000         0
# 2756                     0  ...  20.000000   9.090909  50.000000         0
# 2591                     0  ...  20.000000  18.181818  75.000000         0
# 4043                     0  ...  20.000000   9.090909  75.000000        40
# 816                      0  ...  20.000000   9.090909  50.000000         0
# 2333                     0  ...  20.000000   9.090909  50.000000         0
#
#       %HImaxFou   %HImaxLP  %HImaxTA  %HImaxROW    %HIline  %Hiline_level
# 207         0.0  25.000000         0          0  14.856745           HIGH
# 2577        0.0  25.000000         0          0  17.741291           HIGH
# 4437        0.0  25.000000         0          0  15.121291           HIGH
# 764         0.0  25.000000         0          0  14.856745           HIGH
# 3663       50.0  37.500000       100         50  39.849208         MEDIUM
# 292         0.0  25.000000         0          0  14.856745           HIGH
# 2592        0.0  25.000000         0          0  17.741291           HIGH
# 3452        0.0  25.000000         0          0  15.121291           HIGH
# 3047      100.0  42.500000       100        100  54.169041         MEDIUM
# 3611       50.0  25.000000       100          0  35.226745         MEDIUM
# 1852       90.0  75.000000        90        100  69.340291            LOW
# 1757       90.0  75.000000        90        100  71.917564            LOW
# 4426        0.0  25.000000         0          0  15.121291           HIGH
# 1209        0.0  25.000000         0          0  14.856745           HIGH
# 1597       25.0  31.250000        50          0  28.419370           HIGH
# 3236       90.0  75.000000        90        100  60.228691         MEDIUM
# 4093       37.5  31.250000       100          0  33.899870         MEDIUM
# 1071        0.0  25.000000         0          0  14.856745           HIGH
# 4379        0.0  25.000000         0          0  17.741291           HIGH
# 1694       82.5  65.000000        90        100  64.716082         MEDIUM
# 1899       90.0  75.000000        90        100  69.340291            LOW
# 2581        0.0  25.000000         0          0  17.741291           HIGH
# 200         0.0  25.000000         0          0  14.856745           HIGH
# 3800       37.5  25.000000       100          0  32.844245         MEDIUM
# 2797        0.0  25.000000         0          0  14.856745           HIGH
# 617         0.0  25.000000         0          0   9.616745           HIGH
# 4149       37.5  25.000000       100          0  32.844245         MEDIUM
# 3952       37.5  29.166667       100          0  33.071995         MEDIUM
# 533        37.5  25.000000       100          0  31.296245         MEDIUM
# 3652       50.0  37.500000       100         50  39.849208         MEDIUM
# 4292       90.0  75.000000        90        100  71.917564            LOW
# 2264        0.0  25.000000         0          0  14.856745           HIGH
# 4110       37.5  25.000000       100          0  32.844245         MEDIUM
# 1940       90.0  75.000000        90        100  62.805964         MEDIUM
# 1410        0.0  25.000000         0          0  14.856745           HIGH
# 3065       50.0  50.000000        75         50  49.080852         MEDIUM
# 3051       50.0  50.000000        75         50  49.080852         MEDIUM
# 84          0.0  25.000000         0          0  14.856745           HIGH
# 4010       37.5  33.333333       100          0  35.323745         MEDIUM
# 4256       90.0  75.000000        90        100  71.917564            LOW
# 2349        0.0  25.000000         0          0  14.856745           HIGH
# 4006       37.5  33.333333       100          0  35.323745         MEDIUM
# 111         0.0  25.000000         0          0  14.856745           HIGH
# 1594       25.0  31.250000        50          0  28.419370           HIGH
# 1279        0.0  25.000000         0          0  14.856745           HIGH
# 2756        0.0  25.000000         0          0  14.856745           HIGH
# 2591        0.0  25.000000         0          0  17.741291           HIGH
# 4043       37.5  33.333333       100          0  35.323745         MEDIUM
# 816         0.0  25.000000         0          0  14.856745           HIGH
# 2333        0.0  25.000000         0          0  14.856745           HIGH
#
# [50 rows x 140 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4608 entries, 0 to 4607
# Columns: 140 entries, towerid to %Hiline_level
# dtypes: float64(48), int64(91), object(1)
# memory usage: 4.9+ MB

# %%
df.columns
# Out:
# Index(['towerid', 'conductor_visual', ' Wi_con_vir', 'conductor_zinc',
#        ' Wi_con_zin', 'conductor_tensile', ' Wi_con_ten',
#        'conductor_ductility', ' Wi_con_duc', 'conductor_tensileaac',
#        ...
#        '%HImaxCon', '%HImaxCA', '%HImaxINS', '%HImaxSS', '%HImaxFou',
#        '%HImaxLP', '%HImaxTA', '%HImaxROW', '%HIline', '%Hiline_level'],
#       dtype='object', length=140)

# %% [markdown]
# ## Draw Decision Tree

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import (
    confusion_matrix,
    plot_confusion_matrix,
    classification_report,
    accuracy_score,
    precision_score,
    recall_score,
    precision_recall_fscore_support,
    f1_score,
)

# %%
df.columns
# Out:
# Index(['towerid', 'conductor_visual', ' Wi_con_vir', 'conductor_zinc',
#        ' Wi_con_zin', 'conductor_tensile', ' Wi_con_ten',
#        'conductor_ductility', ' Wi_con_duc', 'conductor_tensileaac',
#        ...
#        '%HImaxCon', '%HImaxCA', '%HImaxINS', '%HImaxSS', '%HImaxFou',
#        '%HImaxLP', '%HImaxTA', '%HImaxROW', '%HIline', '%Hiline_level'],
#       dtype='object', length=140)

# %%
cols = [   "SS-Smax","Con-Smax","joint_resistance","conductor_visual","CA-Smax","protection_overhead","visual_zinc","insulator_fitting", ]

# %%
X = df[cols]  # features
y = df["%Hiline_level"]  # label

# %%
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=test_size, stratify=y, random_state=7
)

# %%
#เนื่องจากค่าตัวแปรมีทั้งหลักหน่วย สิบ ร้อย พัน,ค่าที่สูง dominate ค่าน้อย จึงต้องทำ
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# Fit only to the trainning data
scaler.fit(X_train)

#Now apply the transformations to the data:
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-0.53105711, -0.79780731, -0.15724233, ..., -0.13848557,
#         -0.49812567, -1.62797677],
#        [ 2.53037001,  1.16922797, -0.15724233, ...,  2.06176366,
#          2.50939474,  2.10846307],
#        [-0.53105711, -2.76484258, -0.15724233, ..., -1.6053184 ,
#         -0.49812567, -1.62797677],
#        ...,
#        [-0.53105711,  0.18571033, -0.15724233, ..., -0.13848557,
#         -0.49812567, -0.13340084],
#        [ 0.69351374, -0.79780731, -0.15724233, ..., -1.6053184 ,
#         -0.49812567, -1.62797677],
#        [-0.53105711, -2.76484258, -0.15724233, ..., -1.6053184 ,
#         -0.49812567, -1.62797677]])

# %%
X_train = pd.DataFrame(X_train, columns = X.columns)

X_test = pd.DataFrame(X_test, columns=X.columns)

# %%
model = DecisionTreeClassifier(criterion="gini")  # gini is a default
# model=DecisionTreeClassifier(criterion='entropy')

model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
X_train.columns
# Out:
# Index(['SS-Smax', 'Con-Smax', 'joint_resistance', 'conductor_visual',
#        'CA-Smax', 'protection_overhead', 'visual_zinc', 'insulator_fitting'],
#       dtype='object')

# %%
model.feature_importances_
# Out:
# array([0.64152095, 0.1365352 , 0.05850015, 0.05366108, 0.03549412,
#        0.03700469, 0.01154647, 0.02573735])

# %%
fs = pd.Series(model.feature_importances_, index=X_train.columns).sort_values(
    ascending=False
)
fs
# Out:
# SS-Smax                0.641521
# Con-Smax               0.136535
# joint_resistance       0.058500
# conductor_visual       0.053661
# protection_overhead    0.037005
# CA-Smax                0.035494
# insulator_fitting      0.025737
# visual_zinc            0.011546
# dtype: float64

# %%
y_train.value_counts()
# Out:
# HIGH      2126
# MEDIUM    1280
# LOW        280
# Name: %Hiline_level, dtype: int64

# %% [markdown]
# ## tree diagram

# %%
clf = DecisionTreeClassifier(criterion="gini")
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
clf.__dict__
# Out:
# {'criterion': 'gini',
#  'splitter': 'best',
#  'max_depth': None,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'min_weight_fraction_leaf': 0.0,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'random_state': None,
#  'min_impurity_decrease': 0.0,
#  'class_weight': None,
#  'ccp_alpha': 0.0,
#  'feature_names_in_': array(['SS-Smax', 'Con-Smax', 'joint_resistance', 'conductor_visual',
#         'CA-Smax', 'protection_overhead', 'visual_zinc',
#         'insulator_fitting'], dtype=object),
#  'n_features_in_': 8,
#  'n_outputs_': 1,
#  'classes_': array(['HIGH', 'LOW', 'MEDIUM'], dtype=object),
#  'n_classes_': 3,
#  'max_features_': 8,
#  'tree_': <sklearn.tree._tree.Tree at 0x27a07086a40>}

# %%
clf.__dict__["tree_"]

# %%
type(clf)
# Out:
# sklearn.tree._classes.DecisionTreeClassifier

# %%
clf.__dict__["classes_"]
# Out:
# array(['HIGH', 'LOW', 'MEDIUM'], dtype=object)

# %%
from sklearn.tree import export_graphviz
from graphviz import Digraph, Source


def view_tree(model, X, save_tree_img=False):
    estimators = clf
    dot_graph = export_graphviz(
        estimators,
        feature_names=X.columns,
        class_names=model.__dict__["classes_"],
        rounded=True,
        proportion=False,
        precision=2,
        filled=True,
    )
    #     with open(f'tree{tree_index}.dot') as f:
    #         dot_graph = f.read()
    g = Source(dot_graph)
    if save_tree_img:
        g.render(f"tree", format="png", view=False, cleanup=True)
    return g

# %%
view_tree(clf, X_test, save_tree_img=False)

# %%
cm = confusion_matrix(y_test, model.predict(X_test))
cm
# Out:
# array([[524,   0,   8],
#        [  5,  49,  16],
#        [ 35,  30, 255]], dtype=int64)

# %%
print(classification_report(y, model.predict(X)))
# Out:
#               precision    recall  f1-score   support
#
#         HIGH       0.00      0.00      0.00      2658
#          LOW       0.37      0.70      0.49       350
#       MEDIUM       0.30      0.74      0.43      1600
#
#     accuracy                           0.31      4608
#    macro avg       0.22      0.48      0.30      4608
# weighted avg       0.13      0.31      0.19      4608
# C:\Users\bedm2\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\bedm2\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\bedm2\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
model.tree_.impurity  # gini
# Out:
# array([0.54096847, 0.2530332 , 0.4243667 , 0.43458579, 0.44115296,
#        0.44609044, 0.        , 0.        , 0.15277778, 0.        ,
#        0.5       , 0.        , 0.        , 0.15966535, 0.45184304,
#        0.10493827, 0.08584775, 0.08677686, 0.        , 0.        ,
#        0.45209751, 0.49546485, 0.36281179, 0.        , 0.38132807,
#        0.3944485 , 0.40816327, 0.375     , 0.        , 0.1228849 ,
#        0.09952988, 0.09692121, 0.09601305, 0.        , 0.09839354,
#        0.09972299, 0.09804569, 0.        , 0.09810569, 0.        ,
#        0.        , 0.42438272, 0.41925059, 0.        , 0.36148927,
#        0.29964463, 0.19093347, 0.35788194, 0.15673469, 0.24489796,
#        0.20244898, 0.29065744, 0.375     , 0.44444444, 0.34567901,
#        0.        , 0.10493827, 0.        , 0.21875   , 0.        ,
#        0.27777778, 0.32      , 0.        , 0.40816327, 0.27777778,
#        0.375     , 0.        , 0.        , 0.        , 0.40920415,
#        0.47987309, 0.        , 0.51645148, 0.51104659, 0.46141975,
#        0.40816327, 0.4260355 , 0.        , 0.23553719, 0.39669421,
#        0.        , 0.500534  , 0.48150888, 0.4712    , 0.        ,
#        0.45746528, 0.        , 0.        , 0.19753086, 0.        ,
#        0.32      , 0.        , 0.44444444, 0.5       , 0.        ,
#        0.0416478 , 0.        , 0.24489796, 0.        , 0.44444444,
#        0.        , 0.        , 0.12428261, 0.38995726, 0.30087661,
#        0.16724377, 0.5       , 0.        , 0.48      , 0.5       ,
#        0.        , 0.1077551 , 0.20244898, 0.2688    , 0.        ,
#        0.27777778, 0.        , 0.        , 0.49382716, 0.18      ,
#        0.27777778, 0.        , 0.4567474 , 0.26035503, 0.        ,
#        0.34567901, 0.        , 0.44855821, 0.03733792, 0.        ,
#        0.09751943, 0.48      , 0.        , 0.5       , 0.44444444,
#        0.        , 0.0824157 , 0.49990081, 0.44907198, 0.49940547,
#        0.48816568, 0.4928    , 0.49149338, 0.5       , 0.        ,
#        0.        , 0.10493827, 0.        , 0.18      , 0.24489796,
#        0.        , 0.49738714, 0.49777778, 0.        , 0.23553719,
#        0.        , 0.2401298 ])

# %%
model.tree_.value
# Out:
# array([[[2.126e+03, 2.800e+02, 1.280e+03]],
#
#        [[2.063e+03, 6.100e+01, 2.870e+02]],
#
#        [[1.000e+00, 4.500e+01, 1.070e+02]],
#
#        [[0.000e+00, 4.500e+01, 9.600e+01]],
#
#        [[0.000e+00, 4.500e+01, 9.200e+01]],
#
#        [[0.000e+00, 4.500e+01, 8.900e+01]],
#
#        [[0.000e+00, 0.000e+00, 3.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 4.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 1.100e+01]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+01]],
#
#        [[1.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[2.062e+03, 1.600e+01, 1.800e+02]],
#
#        [[1.140e+02, 0.000e+00, 6.000e+01]],
#
#        [[8.500e+01, 0.000e+00, 5.000e+00]],
#
#        [[8.500e+01, 0.000e+00, 4.000e+00]],
#
#        [[8.400e+01, 0.000e+00, 4.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[2.900e+01, 0.000e+00, 5.500e+01]],
#
#        [[1.900e+01, 0.000e+00, 2.300e+01]],
#
#        [[1.000e+01, 0.000e+00, 3.200e+01]],
#
#        [[0.000e+00, 0.000e+00, 3.000e+00]],
#
#        [[1.000e+01, 0.000e+00, 2.900e+01]],
#
#        [[1.000e+01, 0.000e+00, 2.700e+01]],
#
#        [[6.000e+00, 0.000e+00, 1.500e+01]],
#
#        [[4.000e+00, 0.000e+00, 1.200e+01]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[1.948e+03, 1.600e+01, 1.200e+02]],
#
#        [[1.873e+03, 1.600e+01, 8.700e+01]],
#
#        [[1.873e+03, 1.600e+01, 8.400e+01]],
#
#        [[1.873e+03, 1.500e+01, 8.400e+01]],
#
#        [[5.000e+01, 0.000e+00, 0.000e+00]],
#
#        [[1.823e+03, 1.500e+01, 8.400e+01]],
#
#        [[3.420e+02, 0.000e+00, 1.900e+01]],
#
#        [[1.481e+03, 1.500e+01, 6.500e+01]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[1.480e+03, 1.500e+01, 6.500e+01]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 3.000e+00]],
#
#        [[7.500e+01, 0.000e+00, 3.300e+01]],
#
#        [[7.500e+01, 0.000e+00, 3.200e+01]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[6.300e+01, 2.190e+02, 9.930e+02]],
#
#        [[6.300e+01, 1.430e+02, 9.810e+02]],
#
#        [[6.300e+01, 3.800e+01, 8.730e+02]],
#
#        [[4.400e+01, 9.000e+00, 1.870e+02]],
#
#        [[0.000e+00, 6.000e+00, 6.400e+01]],
#
#        [[0.000e+00, 6.000e+00, 3.600e+01]],
#
#        [[0.000e+00, 4.000e+00, 3.100e+01]],
#
#        [[0.000e+00, 3.000e+00, 1.400e+01]],
#
#        [[0.000e+00, 3.000e+00, 9.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 2.000e+00, 7.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 5.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 1.700e+01]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+01]],
#
#        [[0.000e+00, 1.000e+00, 7.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 5.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 4.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 2.000e+00, 5.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 5.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 3.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.800e+01]],
#
#        [[4.400e+01, 3.000e+00, 1.230e+02]],
#
#        [[4.400e+01, 2.000e+00, 7.700e+01]],
#
#        [[0.000e+00, 0.000e+00, 2.500e+01]],
#
#        [[4.400e+01, 2.000e+00, 5.200e+01]],
#
#        [[4.400e+01, 1.000e+00, 4.400e+01]],
#
#        [[1.300e+01, 0.000e+00, 2.300e+01]],
#
#        [[1.000e+01, 0.000e+00, 4.000e+00]],
#
#        [[9.000e+00, 0.000e+00, 4.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[3.000e+00, 0.000e+00, 1.900e+01]],
#
#        [[3.000e+00, 0.000e+00, 8.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.100e+01]],
#
#        [[3.100e+01, 1.000e+00, 2.100e+01]],
#
#        [[3.100e+01, 0.000e+00, 2.100e+01]],
#
#        [[3.100e+01, 0.000e+00, 1.900e+01]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[3.100e+01, 0.000e+00, 1.700e+01]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 8.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 4.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 4.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 4.600e+01]],
#
#        [[0.000e+00, 0.000e+00, 4.000e+01]],
#
#        [[0.000e+00, 1.000e+00, 6.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 4.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[1.900e+01, 2.900e+01, 6.860e+02]],
#
#        [[1.900e+01, 1.800e+01, 1.190e+02]],
#
#        [[1.900e+01, 0.000e+00, 8.400e+01]],
#
#        [[7.000e+00, 0.000e+00, 6.900e+01]],
#
#        [[3.000e+00, 0.000e+00, 3.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[2.000e+00, 0.000e+00, 3.000e+00]],
#
#        [[2.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[4.000e+00, 0.000e+00, 6.600e+01]],
#
#        [[4.000e+00, 0.000e+00, 3.100e+01]],
#
#        [[4.000e+00, 0.000e+00, 2.100e+01]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[4.000e+00, 0.000e+00, 2.000e+01]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+01]],
#
#        [[0.000e+00, 0.000e+00, 3.500e+01]],
#
#        [[1.200e+01, 0.000e+00, 1.500e+01]],
#
#        [[1.000e+00, 0.000e+00, 9.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 5.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 4.000e+00]],
#
#        [[1.100e+01, 0.000e+00, 6.000e+00]],
#
#        [[1.100e+01, 0.000e+00, 2.000e+00]],
#
#        [[4.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[7.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 4.000e+00]],
#
#        [[0.000e+00, 1.800e+01, 3.500e+01]],
#
#        [[0.000e+00, 1.100e+01, 5.670e+02]],
#
#        [[0.000e+00, 0.000e+00, 3.640e+02]],
#
#        [[0.000e+00, 1.100e+01, 2.030e+02]],
#
#        [[0.000e+00, 2.000e+00, 3.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 2.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 9.000e+00, 2.000e+02]],
#
#        [[0.000e+00, 1.050e+02, 1.080e+02]],
#
#        [[0.000e+00, 1.600e+01, 3.100e+01]],
#
#        [[0.000e+00, 1.500e+01, 1.400e+01]],
#
#        [[0.000e+00, 1.500e+01, 1.100e+01]],
#
#        [[0.000e+00, 1.400e+01, 1.100e+01]],
#
#        [[0.000e+00, 1.300e+01, 1.000e+01]],
#
#        [[0.000e+00, 1.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 3.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 1.700e+01]],
#
#        [[0.000e+00, 0.000e+00, 8.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 9.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 6.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 3.000e+00]],
#
#        [[0.000e+00, 8.900e+01, 7.700e+01]],
#
#        [[0.000e+00, 8.800e+01, 7.700e+01]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 7.600e+01, 1.200e+01]],
#
#        [[0.000e+00, 2.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 7.400e+01, 1.200e+01]]])

# %%
predicted = model.predict(X_test)
predicted
# Out:
# array(['HIGH', 'LOW', 'LOW', 'MEDIUM', 'MEDIUM', 'LOW', 'LOW', 'HIGH',
#        'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'LOW', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'LOW', 'LOW', 'MEDIUM',
#        'LOW', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'LOW', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'LOW', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'LOW', 'MEDIUM', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'LOW', 'LOW', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'LOW', 'LOW', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM',
#        'LOW', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'LOW', 'HIGH', 'LOW',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'LOW', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'LOW', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'LOW', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'LOW', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'LOW', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'LOW', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'LOW', 'MEDIUM', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'LOW', 'HIGH',
#        'HIGH', 'HIGH', 'LOW', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH',
#        'LOW', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'LOW', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'LOW', 'HIGH', 'MEDIUM',
#        'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'LOW', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'MEDIUM', 'MEDIUM', 'LOW', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'HIGH',
#        'HIGH', 'MEDIUM', 'LOW', 'HIGH', 'LOW', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'HIGH', 'LOW', 'HIGH',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'MEDIUM', 'MEDIUM', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'LOW', 'MEDIUM', 'HIGH', 'LOW',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'LOW', 'MEDIUM', 'LOW',
#        'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'LOW', 'HIGH', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'HIGH',
#        'HIGH', 'HIGH', 'LOW', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'LOW', 'HIGH', 'LOW', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'MEDIUM', 'LOW', 'LOW', 'HIGH', 'HIGH', 'HIGH', 'LOW',
#        'HIGH', 'MEDIUM', 'LOW', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'LOW',
#        'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'LOW', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM',
#        'MEDIUM', 'LOW', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'LOW', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'LOW', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM',
#        'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'LOW', 'MEDIUM', 'HIGH', 'HIGH', 'LOW',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH',
#        'LOW', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH',
#        'LOW', 'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'MEDIUM', 'MEDIUM', 'LOW', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'MEDIUM', 'MEDIUM',
#        'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'MEDIUM',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM', 'MEDIUM', 'MEDIUM',
#        'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'LOW', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM',
#        'HIGH', 'HIGH', 'LOW', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'LOW', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'LOW', 'HIGH', 'HIGH', 'LOW',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'LOW',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'LOW', 'LOW', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'MEDIUM', 'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'LOW',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'LOW', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH',
#        'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'LOW',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'LOW', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'LOW',
#        'HIGH', 'HIGH', 'LOW', 'HIGH', 'HIGH'], dtype=object)

# %%
pd.crosstab(y_test, predicted)
# Out:
# col_0          HIGH  LOW  MEDIUM
# %Hiline_level
# HIGH            524    0       8
# LOW               5   49      16
# MEDIUM           35   30     255
