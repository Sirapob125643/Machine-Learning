# %% [markdown]
# ## Classification Tree

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %config InlineBackend.figure_format = 'svg'

# %%
print(f"pandas  version: {pd.__version__}")
print(f"numpy   version: {np.__version__}")
print(f"seaborn version: {sns.__version__}")
# Out:
# pandas  version: 1.4.4
# numpy   version: 1.21.5
# seaborn version: 0.12.0

# %%
df = pd.read_excel("test_filter_error-new_-testV1.xlsx")
df.sample(50)
# Out:
#       Tower        %HIc      %HIca      %HIIn      %HIss     %HIfou  \
# 4696    4697  56.250000  34.000000  47.500000  44.000000  41.666667
# 1066    1067  56.250000  44.000000  93.750000  65.000000  75.000000
# 3557    3558  50.000000  32.000000  68.750000  60.000000  58.333333
# 1286    1287  50.000000  42.500000  53.000000  72.000000  75.000000
# 3781    3782  56.250000  45.000000  66.250000  55.000000  55.000000
# 5797    5798  75.000000  36.000000  66.000000  76.000000  50.000000
# 1727    1728  81.250000  65.000000  72.000000  80.000000  85.000000
# 3482    3483  75.000000  48.000000  77.500000  40.000000  60.000000
# 1152    1153  81.250000  30.000000  53.000000  30.000000  30.000000
# 4653    4654  75.000000  48.000000  81.000000  60.000000  50.000000
# 4810    4811  43.750000  35.000000  32.000000  73.333333  55.000000
# 932      933  58.333333  36.000000  57.500000  44.000000  45.000000
# 2147    2148  83.333333  58.000000  76.000000  64.000000  65.000000
# 5564    5565  85.000000  35.000000  63.000000  86.666667  35.000000
# 3124    3125  45.000000  22.000000  31.000000  56.000000  25.000000
# 894      895  75.000000  38.000000  49.000000  68.000000  75.000000
# 191      192  87.500000  45.000000  61.000000  48.000000  70.000000
# 5451    5452  37.500000  40.000000  56.250000  40.000000  55.000000
# 1649    1650  85.000000  40.000000  84.000000  64.000000  50.000000
# 5397    5398  62.500000  32.500000  53.750000  56.000000  50.000000
# 3092    3093  80.000000  24.000000  84.000000  70.000000  70.000000
# 5224    5225  55.000000  32.500000  71.250000  76.000000  70.000000
# 2706    2707  50.000000  40.000000  61.000000  68.000000  50.000000
# 2026    2027  75.000000  42.000000  83.750000  33.333333  80.000000
# 5407    5408  75.000000  52.500000  68.000000  48.000000  75.000000
# 2983    2984  62.500000  37.500000  41.000000  55.000000  43.750000
# 1957    1958  41.666667  38.000000  87.500000  60.000000  58.333333
# 3729    3730  50.000000  46.666667  56.000000  56.000000  35.000000
# 2945    2946  60.000000  25.000000  64.000000  68.000000  50.000000
# 6125    6126  62.500000  46.000000  62.000000  20.000000  75.000000
# 2898    2899  68.750000  37.500000  60.000000  64.000000  58.333333
# 2446    2447  58.333333  57.500000  58.750000  68.000000  60.000000
# 1873    1874  56.250000  28.000000  63.333333  45.000000  50.000000
# 3135    3136  37.500000  42.000000  37.000000  60.000000  60.000000
# 5628    5629  45.000000  26.000000  51.000000  76.000000  37.500000
# 956      957  55.000000  40.000000  71.000000  36.000000  60.000000
# 5913    5914  50.000000  30.000000  83.333333  46.666667  50.000000
# 2476    2477  66.666667  32.500000  66.250000  32.000000  43.750000
# 2499    2500  50.000000  42.500000  61.250000  48.000000  66.666667
# 3927    3928  83.333333  57.500000  72.000000  64.000000  85.000000
# 4532    4533  68.750000  32.000000  90.000000  60.000000  65.000000
# 477      478  60.000000  40.000000  80.000000  35.000000  80.000000
# 4549    4550  55.000000  42.000000  71.666667  60.000000  65.000000
# 3170    3171  41.666667  44.000000  60.000000  72.000000  55.000000
# 1082    1083  56.250000  40.000000  36.000000  40.000000  37.500000
# 506      507  65.000000  37.500000  61.000000  48.000000  50.000000
# 5504    5505  75.000000  27.500000  51.000000  46.666667  37.500000
# 878      879  55.000000  32.000000  73.333333  80.000000  50.000000
# 3196    3197  43.750000  30.000000  42.500000  40.000000  41.666667
# 4185    4186  43.750000  42.500000  51.000000  64.000000  45.000000
#
#           %HIlp  %HIta  %HIrow    %HIline %HI-Line-level
# 4696  32.000000      0       0  89.710400         MEDIUM
# 1066  56.000000    100       0  86.518850         MEDIUM
# 3557  46.000000    100     100  86.518850         MEDIUM
# 1286  56.000000    100       0  82.720400         MEDIUM
# 3781  52.000000     50     100  82.720400         MEDIUM
# 5797  46.666667     75     100  86.719150         MEDIUM
# 1727  75.000000    100     100  90.366525           HIGH
# 3482  54.000000     50       0  92.130700         MEDIUM
# 1152  27.500000      0       0  92.447426         MEDIUM
# 4653  58.000000     50     100  89.710400         MEDIUM
# 4810  61.666667     50       0  95.595200         MEDIUM
# 932   54.000000     75       0  92.130700         MEDIUM
# 2147  56.000000     75     100  89.710400           HIGH
# 5564  42.000000     50       0  92.489426         MEDIUM
# 3124  35.000000     50       0  92.489426         MEDIUM
# 894   65.000000     50       0  92.130700         MEDIUM
# 191   43.000000     50     100  83.516050           HIGH
# 5451  40.000000     50     100  85.928083         MEDIUM
# 1649  64.000000     50     100  90.366525           HIGH
# 5397  28.000000     50     100  85.928083         MEDIUM
# 3092  36.000000     75       0  92.489426         MEDIUM
# 5224  25.000000    100       0  83.516050         MEDIUM
# 2706  40.000000    100       0  83.516050         MEDIUM
# 2026  42.500000     50       0  88.310167         MEDIUM
# 5407  42.000000     50     100  85.928083         MEDIUM
# 2983  39.000000     50     100  85.928083         MEDIUM
# 1957  31.000000    100     100  84.771650         MEDIUM
# 3729  43.750000     75     100  92.447426         MEDIUM
# 2945  28.000000    100     100  85.928083         MEDIUM
# 6125  44.000000      0     100  92.447426         MEDIUM
# 2898  30.000000     50       0  85.928083         MEDIUM
# 2446  67.000000     75       0  90.574576         MEDIUM
# 1873  45.000000     50     100  93.762026         MEDIUM
# 3135  53.000000     75     100  80.244500         MEDIUM
# 5628  41.000000     75       0  80.244500         MEDIUM
# 956   42.000000     50       0  92.130700         MEDIUM
# 5913  40.000000    100     100  92.130700         MEDIUM
# 2476  43.000000     50       0  90.574576         MEDIUM
# 2499  56.000000     50     100  90.574576         MEDIUM
# 3927  64.000000     75     100  91.614183           HIGH
# 4532  36.000000     75       0  88.310167         MEDIUM
# 477   42.000000      0     100  85.928083         MEDIUM
# 4549  47.500000     50     100  88.310167         MEDIUM
# 3170  47.000000    100       0  80.244500         MEDIUM
# 1082  27.500000     50       0  86.518850         MEDIUM
# 506   38.333333     50       0  92.489426         MEDIUM
# 5504  28.333333      0       0  92.489426         MEDIUM
# 878   37.000000     75       0  92.130700         MEDIUM
# 3196  38.000000     50       0  80.244500         MEDIUM
# 4185  48.000000     50     100  90.366525         MEDIUM

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6250 entries, 0 to 6249
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Tower           6250 non-null   int64
#  1   %HIc            6250 non-null   float64
#  2   %HIca           6250 non-null   float64
#  3   %HIIn           6250 non-null   float64
#  4   %HIss           6250 non-null   float64
#  5   %HIfou          6250 non-null   float64
#  6   %HIlp           6250 non-null   float64
#  7   %HIta           6250 non-null   int64
#  8   %HIrow          6250 non-null   int64
#  9   %HIline         6250 non-null   float64
#  10  %HI-Line-level  6250 non-null   object
# dtypes: float64(7), int64(3), object(1)
# memory usage: 537.2+ KB

# %%
df.columns
# Out:
# Index(['Tower ', '%HIc', '%HIca', '%HIIn', '%HIss', '%HIfou', '%HIlp', '%HIta',
#        '%HIrow', '%HIline', '%HI-Line-level'],
#       dtype='object')

# %%
cols = [
    "%HIc",
    "%HIca",
    "%HIIn",
    "%HIss",
    "%HIfou",
    "%HIlp",
    "%HIta",
    "%HIrow",
    "%HIline",
]

# %%
fig, ax = plt.subplots(nrows=3, ncols=3, figsize=(15, 6))
ax = ax.ravel()
for i, col in enumerate(cols):
    sns.violinplot(x="%HI-Line-level", y=col, data=df, ax=ax[i])

# %% [markdown]
# ## Draw Decision Tree

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import (
    confusion_matrix,
    plot_confusion_matrix,
    classification_report,
    accuracy_score,
    precision_score,
    recall_score,
    precision_recall_fscore_support,
    f1_score,
)

# %%
df.columns
# Out:
# Index(['Tower ', '%HIc', '%HIca', '%HIIn', '%HIss', '%HIfou', '%HIlp', '%HIta',
#        '%HIrow', '%HIline', '%HI-Line-level'],
#       dtype='object')

# %%
cols = [
    "%HIc",
    "%HIca",
    "%HIIn",
    "%HIss",
    "%HIfou",
    "%HIlp",
    "%HIta",
    "%HIrow",
    "%HIline",
]

# %%
X = df[cols]  # features
y = df["%HI-Line-level"]  # label

# %%
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=test_size, stratify=y, random_state=7
)

# %%
model = DecisionTreeClassifier(criterion="gini")  # gini is a default
# model=DecisionTreeClassifier(criterion='entropy')

model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
X_train.columns
# Out:
# Index(['%HIc', '%HIca', '%HIIn', '%HIss', '%HIfou', '%HIlp', '%HIta', '%HIrow',
#        '%HIline'],
#       dtype='object')

# %%
model.feature_importances_
# Out:
# array([0.2528094 , 0.05455897, 0.06734649, 0.13649021, 0.17483881,
#        0.1399515 , 0.01175096, 0.11282197, 0.04943169])

# %%
fs = pd.Series(model.feature_importances_, index=X_train.columns).sort_values(
    ascending=False
)
fs
# Out:
# %HIc       0.252809
# %HIfou     0.174839
# %HIlp      0.139952
# %HIss      0.136490
# %HIrow     0.112822
# %HIIn      0.067346
# %HIca      0.054559
# %HIline    0.049432
# %HIta      0.011751
# dtype: float64

# %%
y_train.value_counts()
# Out:
# MEDIUM    4461
# HIGH       455
# LOW         84
# Name: %HI-Line-level, dtype: int64

# %% [markdown]
# ## tree diagram

# %%
clf = DecisionTreeClassifier(criterion="gini")
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
clf.__dict__
# Out:
# {'criterion': 'gini',
#  'splitter': 'best',
#  'max_depth': None,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'min_weight_fraction_leaf': 0.0,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'random_state': None,
#  'min_impurity_decrease': 0.0,
#  'class_weight': None,
#  'ccp_alpha': 0.0,
#  'feature_names_in_': array(['%HIc', '%HIca', '%HIIn', '%HIss', '%HIfou', '%HIlp', '%HIta',
#         '%HIrow', '%HIline'], dtype=object),
#  'n_features_in_': 9,
#  'n_outputs_': 1,
#  'classes_': array(['HIGH', 'LOW', 'MEDIUM'], dtype=object),
#  'n_classes_': 3,
#  'max_features_': 9,
#  'tree_': <sklearn.tree._tree.Tree at 0x1e99fcbc180>}

# %%
clf.__dict__["tree_"]

# %%
type(clf)
# Out:
# sklearn.tree._classes.DecisionTreeClassifier

# %%
clf.__dict__["classes_"]
# Out:
# array(['HIGH', 'LOW', 'MEDIUM'], dtype=object)

# %%
from sklearn.tree import export_graphviz
from graphviz import Digraph, Source


def view_tree(model, X, save_tree_img=False):
    estimators = clf
    dot_graph = export_graphviz(
        estimators,
        feature_names=X.columns,
        class_names=model.__dict__["classes_"],
        rounded=True,
        proportion=False,
        precision=2,
        filled=True,
    )
    #     with open(f'tree{tree_index}.dot') as f:
    #         dot_graph = f.read()
    g = Source(dot_graph)
    if save_tree_img:
        g.render(f"tree", format="png", view=False, cleanup=True)
    return g

# %%
view_tree(clf, X_test, save_tree_img=False)

# %%
cm = confusion_matrix(y_test, model.predict(X_test))
cm
# Out:
# array([[ 108,    0,    6],
#        [   0,   21,    0],
#        [  10,    0, 1105]], dtype=int64)

# %%
print(classification_report(y, model.predict(X)))
# Out:
#               precision    recall  f1-score   support
#
#         HIGH       0.98      0.99      0.99       569
#          LOW       1.00      1.00      1.00       105
#       MEDIUM       1.00      1.00      1.00      5576
#
#     accuracy                           1.00      6250
#    macro avg       0.99      1.00      0.99      6250
# weighted avg       1.00      1.00      1.00      6250

# %%
model.tree_.impurity  # gini
# Out:
# array([0.19541592, 0.08583973, 0.45307227, 0.40047337, 0.19753086,
#        0.09070295, 0.        , 0.        , 0.        , 0.455     ,
#        0.34567901, 0.        , 0.        , 0.        , 0.21176269,
#        0.495     , 0.26035503, 0.        , 0.        , 0.        ,
#        0.04442149, 0.        , 0.        , 0.05900097, 0.03079164,
#        0.46875   , 0.        , 0.        , 0.02569028, 0.28931979,
#        0.35502959, 0.        , 0.        , 0.        , 0.02008513,
#        0.00816018, 0.48      , 0.        , 0.        , 0.00681449,
#        0.00614751, 0.00292157, 0.0973044 , 0.        , 0.        ,
#        0.00148285, 0.03844675, 0.        , 0.        , 0.00075586,
#        0.        , 0.00793638, 0.24489796, 0.        , 0.        ,
#        0.        , 0.05231819, 0.        , 0.28537455, 0.49586777,
#        0.        , 0.        , 0.        , 0.27777778, 0.        ,
#        0.        , 0.12088047, 0.06507273, 0.015872  , 0.        ,
#        0.12444444, 0.        , 0.375     , 0.        , 0.        ,
#        0.28248076, 0.        , 0.48      , 0.        , 0.32      ,
#        0.        , 0.        , 0.47704082, 0.        , 0.4567474 ,
#        0.        , 0.26035503, 0.        , 0.        , 0.27593744,
#        0.08181752, 0.0266618 , 0.00909072, 0.        , 0.44444444,
#        0.        , 0.        , 0.44444444, 0.        , 0.        ,
#        0.48611111, 0.        , 0.        , 0.47473109, 0.13875   ,
#        0.        , 0.48      , 0.        , 0.        , 0.49842192,
#        0.26367188, 0.        , 0.27777778, 0.        , 0.        ,
#        0.38781163, 0.        , 0.31065089, 0.2688    , 0.4536862 ,
#        0.        , 0.27777778, 0.        , 0.1171875 , 0.        ,
#        0.        , 0.        , 0.        , 0.43940101, 0.26135608,
#        0.        , 0.42714476, 0.36234949, 0.20536836, 0.09410842,
#        0.02161904, 0.01092863, 0.        , 0.05401235, 0.        ,
#        0.27777778, 0.        , 0.        , 0.        , 0.48753463,
#        0.        , 0.47337278, 0.46875   , 0.        , 0.        ,
#        0.        , 0.49704142, 0.34026465, 0.        , 0.        ,
#        0.3046875 , 0.        , 0.        , 0.48366962, 0.45429962,
#        0.12841855, 0.        , 0.40816327, 0.        , 0.        ,
#        0.13265306, 0.        , 0.        , 0.255     , 0.48      ,
#        0.        , 0.        , 0.        , 0.32986111, 0.46875   ,
#        0.        , 0.16528926, 0.        , 0.        , 0.        ,
#        0.44900085, 0.45918367, 0.        , 0.4960298 , 0.        ,
#        0.45209751, 0.39349112, 0.1723356 , 0.        , 0.        ,
#        0.        , 0.28537455, 0.        , 0.11072664, 0.48      ,
#        0.        , 0.        , 0.04253308, 0.27777778, 0.        ,
#        0.        , 0.        , 0.23495691, 0.49685059, 0.2268431 ,
#        0.09070295, 0.        , 0.        , 0.        , 0.34875   ,
#        0.        , 0.16089965, 0.44444444, 0.        , 0.        ,
#        0.        , 0.02394858, 0.1171875 , 0.44444444, 0.        ,
#        0.        , 0.        , 0.        ])

# %%
model.tree_.value
# Out:
# array([[[4.550e+02, 8.400e+01, 4.461e+03]],
#
#        [[8.800e+01, 8.400e+01, 3.702e+03]],
#
#        [[0.000e+00, 6.000e+01, 1.130e+02]],
#
#        [[0.000e+00, 4.700e+01, 1.800e+01]],
#
#        [[0.000e+00, 4.000e+01, 5.000e+00]],
#
#        [[0.000e+00, 4.000e+01, 2.000e+00]],
#
#        [[0.000e+00, 4.000e+01, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 3.000e+00]],
#
#        [[0.000e+00, 7.000e+00, 1.300e+01]],
#
#        [[0.000e+00, 7.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 7.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.100e+01]],
#
#        [[0.000e+00, 1.300e+01, 9.500e+01]],
#
#        [[0.000e+00, 1.100e+01, 9.000e+00]],
#
#        [[0.000e+00, 1.100e+01, 2.000e+00]],
#
#        [[0.000e+00, 1.100e+01, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 7.000e+00]],
#
#        [[0.000e+00, 2.000e+00, 8.600e+01]],
#
#        [[0.000e+00, 2.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 8.600e+01]],
#
#        [[8.800e+01, 2.400e+01, 3.589e+03]],
#
#        [[2.800e+01, 2.400e+01, 3.286e+03]],
#
#        [[0.000e+00, 9.000e+00, 1.500e+01]],
#
#        [[0.000e+00, 9.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.500e+01]],
#
#        [[2.800e+01, 1.500e+01, 3.271e+03]],
#
#        [[0.000e+00, 1.000e+01, 4.700e+01]],
#
#        [[0.000e+00, 1.000e+01, 3.000e+00]],
#
#        [[0.000e+00, 1.000e+01, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 3.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 4.400e+01]],
#
#        [[2.800e+01, 5.000e+00, 3.224e+03]],
#
#        [[7.000e+00, 5.000e+00, 2.920e+03]],
#
#        [[0.000e+00, 2.000e+00, 3.000e+00]],
#
#        [[0.000e+00, 2.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 3.000e+00]],
#
#        [[7.000e+00, 3.000e+00, 2.917e+03]],
#
#        [[6.000e+00, 3.000e+00, 2.912e+03]],
#
#        [[1.000e+00, 3.000e+00, 2.731e+03]],
#
#        [[0.000e+00, 2.000e+00, 3.700e+01]],
#
#        [[0.000e+00, 0.000e+00, 3.700e+01]],
#
#        [[0.000e+00, 2.000e+00, 0.000e+00]],
#
#        [[1.000e+00, 1.000e+00, 2.694e+03]],
#
#        [[0.000e+00, 1.000e+00, 5.000e+01]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 5.000e+01]],
#
#        [[1.000e+00, 0.000e+00, 2.644e+03]],
#
#        [[0.000e+00, 0.000e+00, 2.394e+03]],
#
#        [[1.000e+00, 0.000e+00, 2.500e+02]],
#
#        [[1.000e+00, 0.000e+00, 6.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 6.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.440e+02]],
#
#        [[5.000e+00, 0.000e+00, 1.810e+02]],
#
#        [[0.000e+00, 0.000e+00, 1.570e+02]],
#
#        [[5.000e+00, 0.000e+00, 2.400e+01]],
#
#        [[5.000e+00, 0.000e+00, 6.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 6.000e+00]],
#
#        [[5.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.800e+01]],
#
#        [[1.000e+00, 0.000e+00, 5.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 5.000e+00]],
#
#        [[2.100e+01, 0.000e+00, 3.040e+02]],
#
#        [[1.000e+01, 0.000e+00, 2.870e+02]],
#
#        [[2.000e+00, 0.000e+00, 2.480e+02]],
#
#        [[0.000e+00, 0.000e+00, 2.200e+02]],
#
#        [[2.000e+00, 0.000e+00, 2.800e+01]],
#
#        [[0.000e+00, 0.000e+00, 2.200e+01]],
#
#        [[2.000e+00, 0.000e+00, 6.000e+00]],
#
#        [[2.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 6.000e+00]],
#
#        [[8.000e+00, 0.000e+00, 3.900e+01]],
#
#        [[0.000e+00, 0.000e+00, 2.700e+01]],
#
#        [[8.000e+00, 0.000e+00, 1.200e+01]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+01]],
#
#        [[8.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[8.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[1.100e+01, 0.000e+00, 1.700e+01]],
#
#        [[0.000e+00, 0.000e+00, 1.100e+01]],
#
#        [[1.100e+01, 0.000e+00, 6.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 4.000e+00]],
#
#        [[1.100e+01, 0.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[1.100e+01, 0.000e+00, 0.000e+00]],
#
#        [[6.000e+01, 0.000e+00, 3.030e+02]],
#
#        [[1.000e+01, 0.000e+00, 2.240e+02]],
#
#        [[3.000e+00, 0.000e+00, 2.190e+02]],
#
#        [[1.000e+00, 0.000e+00, 2.180e+02]],
#
#        [[0.000e+00, 0.000e+00, 2.160e+02]],
#
#        [[1.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[2.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[2.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[7.000e+00, 0.000e+00, 5.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 5.000e+00]],
#
#        [[7.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[5.000e+01, 0.000e+00, 7.900e+01]],
#
#        [[3.000e+00, 0.000e+00, 3.700e+01]],
#
#        [[0.000e+00, 0.000e+00, 3.500e+01]],
#
#        [[3.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[3.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[4.700e+01, 0.000e+00, 4.200e+01]],
#
#        [[5.000e+00, 0.000e+00, 2.700e+01]],
#
#        [[0.000e+00, 0.000e+00, 2.600e+01]],
#
#        [[5.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[5.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[4.200e+01, 0.000e+00, 1.500e+01]],
#
#        [[0.000e+00, 0.000e+00, 5.000e+00]],
#
#        [[4.200e+01, 0.000e+00, 1.000e+01]],
#
#        [[4.200e+01, 0.000e+00, 8.000e+00]],
#
#        [[1.500e+01, 0.000e+00, 8.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 5.000e+00]],
#
#        [[1.500e+01, 0.000e+00, 3.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[1.500e+01, 0.000e+00, 1.000e+00]],
#
#        [[1.500e+01, 0.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[2.700e+01, 0.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[3.670e+02, 0.000e+00, 7.590e+02]],
#
#        [[1.150e+02, 0.000e+00, 6.290e+02]],
#
#        [[0.000e+00, 0.000e+00, 3.720e+02]],
#
#        [[1.150e+02, 0.000e+00, 2.570e+02]],
#
#        [[7.700e+01, 0.000e+00, 2.470e+02]],
#
#        [[2.800e+01, 0.000e+00, 2.130e+02]],
#
#        [[1.000e+01, 0.000e+00, 1.920e+02]],
#
#        [[2.000e+00, 0.000e+00, 1.810e+02]],
#
#        [[1.000e+00, 0.000e+00, 1.810e+02]],
#
#        [[0.000e+00, 0.000e+00, 1.460e+02]],
#
#        [[1.000e+00, 0.000e+00, 3.500e+01]],
#
#        [[0.000e+00, 0.000e+00, 3.000e+01]],
#
#        [[1.000e+00, 0.000e+00, 5.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 5.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[8.000e+00, 0.000e+00, 1.100e+01]],
#
#        [[0.000e+00, 0.000e+00, 6.000e+00]],
#
#        [[8.000e+00, 0.000e+00, 5.000e+00]],
#
#        [[3.000e+00, 0.000e+00, 5.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 5.000e+00]],
#
#        [[3.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[5.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[1.800e+01, 0.000e+00, 2.100e+01]],
#
#        [[5.000e+00, 0.000e+00, 1.800e+01]],
#
#        [[5.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.800e+01]],
#
#        [[1.300e+01, 0.000e+00, 3.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 3.000e+00]],
#
#        [[1.300e+01, 0.000e+00, 0.000e+00]],
#
#        [[4.900e+01, 0.000e+00, 3.400e+01]],
#
#        [[1.500e+01, 0.000e+00, 2.800e+01]],
#
#        [[2.000e+00, 0.000e+00, 2.700e+01]],
#
#        [[0.000e+00, 0.000e+00, 2.200e+01]],
#
#        [[2.000e+00, 0.000e+00, 5.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 5.000e+00]],
#
#        [[2.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[1.300e+01, 0.000e+00, 1.000e+00]],
#
#        [[1.300e+01, 0.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[3.400e+01, 0.000e+00, 6.000e+00]],
#
#        [[4.000e+00, 0.000e+00, 6.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 6.000e+00]],
#
#        [[4.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[3.000e+01, 0.000e+00, 0.000e+00]],
#
#        [[3.800e+01, 0.000e+00, 1.000e+01]],
#
#        [[6.000e+00, 0.000e+00, 1.000e+01]],
#
#        [[5.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 1.000e+01]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+01]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[3.200e+01, 0.000e+00, 0.000e+00]],
#
#        [[2.520e+02, 0.000e+00, 1.300e+02]],
#
#        [[5.500e+01, 0.000e+00, 9.900e+01]],
#
#        [[0.000e+00, 0.000e+00, 5.300e+01]],
#
#        [[5.500e+01, 0.000e+00, 4.600e+01]],
#
#        [[0.000e+00, 0.000e+00, 1.700e+01]],
#
#        [[5.500e+01, 0.000e+00, 2.900e+01]],
#
#        [[7.000e+00, 0.000e+00, 1.900e+01]],
#
#        [[2.000e+00, 0.000e+00, 1.900e+01]],
#
#        [[0.000e+00, 0.000e+00, 1.900e+01]],
#
#        [[2.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[5.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[4.800e+01, 0.000e+00, 1.000e+01]],
#
#        [[0.000e+00, 0.000e+00, 7.000e+00]],
#
#        [[4.800e+01, 0.000e+00, 3.000e+00]],
#
#        [[3.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[3.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[4.500e+01, 0.000e+00, 1.000e+00]],
#
#        [[5.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[5.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[4.000e+01, 0.000e+00, 0.000e+00]],
#
#        [[1.970e+02, 0.000e+00, 3.100e+01]],
#
#        [[3.400e+01, 0.000e+00, 2.900e+01]],
#
#        [[3.000e+00, 0.000e+00, 2.000e+01]],
#
#        [[1.000e+00, 0.000e+00, 2.000e+01]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+01]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[2.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[3.100e+01, 0.000e+00, 9.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 6.000e+00]],
#
#        [[3.100e+01, 0.000e+00, 3.000e+00]],
#
#        [[6.000e+00, 0.000e+00, 3.000e+00]],
#
#        [[6.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 3.000e+00]],
#
#        [[2.500e+01, 0.000e+00, 0.000e+00]],
#
#        [[1.630e+02, 0.000e+00, 2.000e+00]],
#
#        [[3.000e+01, 0.000e+00, 2.000e+00]],
#
#        [[4.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[4.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[2.600e+01, 0.000e+00, 0.000e+00]],
#
#        [[1.330e+02, 0.000e+00, 0.000e+00]]])

# %%
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D

# %%
# switch to interactive matplotlib
# %matplotlib qt
# %pylab qt

# switch back to inline mode
# %matplotlib inline

# %% [markdown]
# ## 3D scatter

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection="3d")
colors = y.map({"LOW": "green", "MEDIUM": "yellow", "HIGH": "red"})
ax.scatter(X["%HIc"], X["%HIss"], X["%HIta"], alpha=0.5, c=colors)
ax.set_xlabel("%HIc")
ax.set_ylabel("%HIss")
ax.set_zlabel("%HIta")
# Out:
# Text(0.5, 0, '%HIta')

# %%
predicted = model.predict(X_test)
predicted
# Out:
# array(['MEDIUM', 'MEDIUM', 'MEDIUM', ..., 'MEDIUM', 'MEDIUM', 'MEDIUM'],
#       dtype=object)

# %%
pd.crosstab(y_test, predicted)
# Out:
# col_0           HIGH  LOW  MEDIUM
# %HI-Line-level
# HIGH             108    0       6
# LOW                0   21       0
# MEDIUM            10    0    1105
