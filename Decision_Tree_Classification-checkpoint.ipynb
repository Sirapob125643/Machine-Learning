# 892                      0  ...  20.000000   9.090909  50.000000       0.0
# 3913                     0  ...  20.000000   9.090909  50.000000      40.0
# 2466                     0  ...  20.000000   9.090909  50.000000       0.0
# 1104                     0  ...  20.000000   9.090909  50.000000       0.0
# 2993                     0  ...  33.333333  30.303030  91.666667      60.0
# 70                       0  ...  20.000000   9.090909  50.000000       0.0
# 1910                     0  ...  20.000000  52.727273  85.000000      88.0
# 852                      0  ...  20.000000   9.090909  50.000000       0.0
# 1099                     0  ...  20.000000   9.090909  50.000000       0.0
# 219                      0  ...  20.000000   9.090909  50.000000       0.0
# 1560                     0  ...  20.000000   9.090909  50.000000      40.0
# 2286                     0  ...  20.000000   9.090909  50.000000       0.0
# 2458                     0  ...  20.000000   9.090909  50.000000       0.0
# 2673                     0  ...  20.000000   9.090909  50.000000       0.0
#
#       %HImaxFou  %HImaxLP  %HImaxTA  %HImaxROW    %HIline  %Hiline_level
# 1558      25.00     31.25        50        0.0  28.419370           HIGH
# 1677      82.50     65.00        90      100.0  64.716082         MEDIUM
# 3906      37.50     25.00       100        0.0  31.296245         MEDIUM
# 2910      50.00     56.25       100       50.0  63.725307         MEDIUM
# 1504       0.00     25.00         0        0.0  14.856745           HIGH
# 4505       0.00     25.00         0        0.0  15.121291           HIGH
# 1454       0.00      0.00         0        0.0   5.129700           HIGH
# 62         0.00     25.00         0        0.0  14.856745           HIGH
# 2765       0.00     25.00         0        0.0  14.856745           HIGH
# 4586       0.00     25.00         0        0.0  15.121291           HIGH
# 1805      90.00     75.00       100      100.0  72.227564            LOW
# 408        0.00     25.00         0        0.0  14.856745           HIGH
# 4485       0.00     25.00         0        0.0  15.121291           HIGH
# 3780      50.00     25.00       100        0.0  33.678745         MEDIUM
# 3851      37.50     31.25       100        0.0  30.803870         MEDIUM
# 4551       0.00     25.00         0        0.0  15.121291           HIGH
# 2394       0.00     25.00         0        0.0  17.741291           HIGH
# 2193       0.00     25.00         0        0.0  14.856745           HIGH
# 3043     100.00     42.50       100      100.0  54.169041         MEDIUM
# 1563      25.00     31.25        50        0.0  28.419370           HIGH
# 1055       0.00     25.00         0        0.0  14.856745           HIGH
# 424        0.00     25.00         0        0.0  14.856745           HIGH
# 351        0.00     25.00         0        0.0  14.856745           HIGH
# 3059      50.00     50.00        75       50.0  49.080852         MEDIUM
# 2818       0.00     25.00         0        0.0  14.856745           HIGH
# 4326      31.25     25.00       100        0.0  34.537541         MEDIUM
# 1023       0.00     25.00         0        0.0  14.856745           HIGH
# 3413       0.00     25.00         0        0.0  15.121291           HIGH
# 2811       0.00     25.00         0        0.0  14.856745           HIGH
# 813        0.00     25.00         0        0.0  14.856745           HIGH
# 3667      50.00     37.50       100       50.0  39.849208         MEDIUM
# 1623      50.00     25.00        50        0.0  30.580745         MEDIUM
# 3745      37.50     31.25       100        0.0  32.351870         MEDIUM
# 886        0.00     25.00         0        0.0  14.856745           HIGH
# 1514       0.00     25.00         0        0.0  14.856745           HIGH
# 3548       0.00     25.00         0        0.0  15.121291           HIGH
# 892        0.00     25.00         0        0.0  14.856745           HIGH
# 3913      37.50     25.00       100        0.0  31.296245         MEDIUM
# 2466       0.00     25.00         0        0.0  14.856745           HIGH
# 1104       0.00     25.00         0        0.0  14.856745           HIGH
# 2993     100.00     50.00       100      100.0  59.885852         MEDIUM
# 70         0.00     25.00         0        0.0  14.856745           HIGH
# 1910      90.00     75.00        90      100.0  62.805964         MEDIUM
# 852        0.00     25.00         0        0.0  14.856745           HIGH
# 1099       0.00     25.00         0        0.0  14.856745           HIGH
# 219        0.00     25.00         0        0.0  14.856745           HIGH
# 1560      25.00     31.25        50        0.0  28.419370           HIGH
# 2286       0.00     25.00         0        0.0  14.856745           HIGH
# 2458       0.00     25.00         0        0.0  14.856745           HIGH
# 2673       0.00     25.00         0        0.0  14.856745           HIGH
#
# [50 rows x 140 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4608 entries, 0 to 4607
# Columns: 140 entries, towerid to %Hiline_level
# dtypes: float64(50), int64(89), object(1)
# memory usage: 4.9+ MB

# %%
df.columns
# Out:
# Index(['towerid', 'conductor_visual', ' Wi_con_vir', 'conductor_zinc',
#        ' Wi_con_zin', 'conductor_tensile', ' Wi_con_ten',
#        'conductor_ductility', ' Wi_con_duc', 'conductor_tensileaac',
#        ...
#        '%HImaxCon', '%HImaxCA', '%HImaxINS', '%HImaxSS', '%HImaxFou',
#        '%HImaxLP', '%HImaxTA', '%HImaxROW', '%HIline', '%Hiline_level'],
#       dtype='object', length=140)

# %%
cols = [
    "%Hic",
    "%Hica",
    "%HIins",
    "%HIss",
    "%HIfound",
    "%Hilp",
    "%Hitowacc",
    "%HIrow",
    "%HItower",
]

# %%
fig, ax = plt.subplots(nrows=3, ncols=3, figsize=(15, 6))
ax = ax.ravel()
for i, col in enumerate(cols):
    sns.violinplot(x="%Hiline_level", y=col, data=df, ax=ax[i])

# %% [markdown]
# ## Draw Decision Tree

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import (
    confusion_matrix,
    plot_confusion_matrix,
    classification_report,
    accuracy_score,
    precision_score,
    recall_score,
    precision_recall_fscore_support,
    f1_score,
)

# %%
df.columns
# Out:
# Index(['towerid', 'conductor_visual', ' Wi_con_vir', 'conductor_zinc',
#        ' Wi_con_zin', 'conductor_tensile', ' Wi_con_ten',
#        'conductor_ductility', ' Wi_con_duc', 'conductor_tensileaac',
#        ...
#        '%HImaxCon', '%HImaxCA', '%HImaxINS', '%HImaxSS', '%HImaxFou',
#        '%HImaxLP', '%HImaxTA', '%HImaxROW', '%HIline', '%Hiline_level'],
#       dtype='object', length=140)

# %%
cols = [
    "%Hic",
    "%Hica",
    "%HIins",
    "%HIss",
    "%HIfound",
    "%Hilp",
    "%Hitowacc",
    "%HIrow",
    "%HItower",
]

# %%
X = df[cols]  # features
y = df["%Hiline_level"]  # label

# %%
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=test_size, stratify=y, random_state=7
)

# %%
#เนื่องจากค่าตัวแปรมีทั้งหลักหน่วย สิบ ร้อย พัน,ค่าที่สูง dominate ค่าน้อย จึงต้องทำ
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# Fit only to the trainning data
scaler.fit(X_train)

#Now apply the transformations to the data:
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-0.0687798 , -0.28218971, -2.39387667, ..., -0.64989218,
#         -0.39244594, -0.69543697],
#        [-0.0687798 ,  0.84343393,  1.33390191, ...,  1.70827279,
#          2.60559707,  2.37824715],
#        [-2.2832711 , -1.40781336, -2.39387667, ..., -0.64989218,
#         -0.39244594, -1.21600697],
#        ...,
#        [-0.0687798 , -0.28218971,  0.26882231, ..., -0.64989218,
#         -0.39244594, -0.40977629],
#        [-0.0687798 , -0.28218971, -2.39387667, ..., -0.64989218,
#         -0.39244594, -0.75684856],
#        [-2.2832711 , -1.40781336, -2.39387667, ..., -0.64989218,
#         -0.39244594, -1.21600697]])

# %%
X_train = pd.DataFrame(X_train, columns = X.columns)

X_test = pd.DataFrame(X_test, columns=X.columns)

# %%
model = DecisionTreeClassifier(criterion="gini")  # gini is a default
# model=DecisionTreeClassifier(criterion='entropy')

model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
X_train.columns
# Out:
# Index(['%Hic', '%Hica', '%HIins', '%HIss', '%HIfound', '%Hilp', '%Hitowacc',
#        '%HIrow', '%HItower'],
#       dtype='object')

# %%
model.feature_importances_
# Out:
# array([0.12611973, 0.01452972, 0.00664801, 0.64803129, 0.00382442,
#        0.02397432, 0.0191137 , 0.        , 0.15775881])

# %%
fs = pd.Series(model.feature_importances_, index=X_train.columns).sort_values(
    ascending=False
)
fs
# Out:
# %HIss        0.648031
# %HItower     0.157759
# %Hic         0.126120
# %Hilp        0.023974
# %Hitowacc    0.019114
# %Hica        0.014530
# %HIins       0.006648
# %HIfound     0.003824
# %HIrow       0.000000
# dtype: float64

# %%
y_train.value_counts()
# Out:
# HIGH      2126
# MEDIUM    1280
# LOW        280
# Name: %Hiline_level, dtype: int64

# %% [markdown]
# ## tree diagram

# %%
clf = DecisionTreeClassifier(criterion="gini")
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
clf.__dict__
# Out:
# {'criterion': 'gini',
#  'splitter': 'best',
#  'max_depth': None,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'min_weight_fraction_leaf': 0.0,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'random_state': None,
#  'min_impurity_decrease': 0.0,
#  'class_weight': None,
#  'ccp_alpha': 0.0,
#  'feature_names_in_': array(['%Hic', '%Hica', '%HIins', '%HIss', '%HIfound', '%Hilp',
#         '%Hitowacc', '%HIrow', '%HItower'], dtype=object),
#  'n_features_in_': 9,
#  'n_outputs_': 1,
#  'classes_': array(['HIGH', 'LOW', 'MEDIUM'], dtype=object),
#  'n_classes_': 3,
#  'max_features_': 9,
#  'tree_': <sklearn.tree._tree.Tree at 0x16eef3822d0>}

# %%
clf.__dict__["tree_"]

# %%
type(clf)
# Out:
# sklearn.tree._classes.DecisionTreeClassifier

# %%
clf.__dict__["classes_"]
# Out:
# array(['HIGH', 'LOW', 'MEDIUM'], dtype=object)

# %%
from sklearn.tree import export_graphviz
from graphviz import Digraph, Source


def view_tree(model, X, save_tree_img=False):
    estimators = clf
    dot_graph = export_graphviz(
        estimators,
        feature_names=X.columns,
        class_names=model.__dict__["classes_"],
        rounded=True,
        proportion=False,
        precision=2,
        filled=True,
    )
    #     with open(f'tree{tree_index}.dot') as f:
    #         dot_graph = f.read()
    g = Source(dot_graph)
    if save_tree_img:
        g.render(f"tree", format="png", view=False, cleanup=True)
    return g

# %%
view_tree(clf, X_test, save_tree_img=False)

# %%
cm = confusion_matrix(y_test, model.predict(X_test))
cm
# Out:
# array([[524,   0,   8],
#        [  5,  48,  17],
#        [ 41,  29, 250]], dtype=int64)

# %%
print(classification_report(y, model.predict(X)))
# Out:
#               precision    recall  f1-score   support
#
#         HIGH       0.00      0.00      0.00      2658
#          LOW       0.08      1.00      0.14       350
#       MEDIUM       0.67      0.00      0.00      1600
#
#     accuracy                           0.08      4608
#    macro avg       0.25      0.33      0.05      4608
# weighted avg       0.24      0.08      0.01      4608
# C:\Users\bedm2\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\bedm2\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\bedm2\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
model.tree_.impurity  # gini
# Out:
# array([0.54096847, 0.2530332 , 0.4243667 , 0.46560064, 0.06243496,
#        0.        , 0.5       , 0.        , 0.        , 0.15966535,
#        0.4430723 , 0.0232526 , 0.4994856 , 0.50576701, 0.4937565 ,
#        0.5196281 , 0.49256395, 0.44444444, 0.        , 0.        ,
#        0.34567901, 0.        , 0.39111111, 0.495     , 0.44444444,
#        0.47530864, 0.45918367, 0.5       , 0.        , 0.48753463,
#        0.49382716, 0.        , 0.        , 0.12134726, 0.11579134,
#        0.28600751, 0.        , 0.38358844, 0.09257124, 0.09763434,
#        0.        , 0.09788533, 0.07094191, 0.07133059, 0.        ,
#        0.21875   , 0.24489796, 0.        , 0.36148927, 0.2094507 ,
#        0.40289566, 0.48753463, 0.5       , 0.49382716, 0.        ,
#        0.48816568, 0.4928    , 0.        , 0.32      , 0.        ,
#        0.37920328, 0.40347559, 0.1957648 , 0.18489796, 0.25262728,
#        0.22569444, 0.        , 0.28673297, 0.52040816, 0.29752066,
#        0.18      , 0.375     , 0.5       , 0.        , 0.        ,
#        0.        , 0.        , 0.21488078, 0.17078189, 0.06887755,
#        0.        , 0.32      , 0.        , 0.        , 0.26923077,
#        0.        , 0.2112    , 0.32      , 0.        , 0.56      ,
#        0.        , 0.375     , 0.5       , 0.        , 0.        ,
#        0.        , 0.44444444, 0.        , 0.        , 0.        ,
#        0.        , 0.51154201, 0.49952173, 0.35123967, 0.1171875 ,
#        0.        , 0.18      , 0.44444444, 0.48      , 0.        ,
#        0.49586777, 0.        , 0.47086801, 0.46537396, 0.32      ,
#        0.34567901, 0.        , 0.48166591, 0.27777778, 0.44444444,
#        0.        , 0.4497323 , 0.        , 0.20761246, 0.        ,
#        0.1171875 , 0.        , 0.375     , 0.        , 0.        ,
#        0.29025413, 0.42      , 0.        , 0.4567474 , 0.14292581,
#        0.07751111, 0.05401235, 0.        , 0.09070295, 0.10493827,
#        0.        , 0.11386593, 0.1171875 , 0.        , 0.        ,
#        0.44444444, 0.375     , 0.        , 0.        , 0.03350042,
#        0.13265306, 0.        , 0.48979592, 0.02526662, 0.        ,
#        0.06534575, 0.45523591, 0.49777778, 0.23330388, 0.        ,
#        0.2401298 ])

# %%
model.tree_.value
# Out:
# array([[[2.126e+03, 2.800e+02, 1.280e+03]],
#
#        [[2.063e+03, 6.100e+01, 2.870e+02]],
#
#        [[1.000e+00, 4.500e+01, 1.070e+02]],
#
#        [[0.000e+00, 4.500e+01, 7.700e+01]],
#
#        [[1.000e+00, 0.000e+00, 3.000e+01]],
#
#        [[0.000e+00, 0.000e+00, 2.900e+01]],
#
#        [[1.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[2.062e+03, 1.600e+01, 1.800e+02]],
#
#        [[1.300e+02, 1.000e+00, 6.200e+01]],
#
#        [[8.400e+01, 0.000e+00, 1.000e+00]],
#
#        [[4.600e+01, 1.000e+00, 6.100e+01]],
#
#        [[4.600e+01, 1.000e+00, 5.500e+01]],
#
#        [[2.400e+01, 1.000e+00, 3.700e+01]],
#
#        [[2.000e+01, 1.000e+00, 2.300e+01]],
#
#        [[1.800e+01, 0.000e+00, 2.300e+01]],
#
#        [[2.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[2.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[4.000e+00, 0.000e+00, 1.400e+01]],
#
#        [[0.000e+00, 0.000e+00, 3.000e+00]],
#
#        [[4.000e+00, 0.000e+00, 1.100e+01]],
#
#        [[2.200e+01, 0.000e+00, 1.800e+01]],
#
#        [[1.400e+01, 0.000e+00, 7.000e+00]],
#
#        [[1.100e+01, 0.000e+00, 7.000e+00]],
#
#        [[9.000e+00, 0.000e+00, 5.000e+00]],
#
#        [[2.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[3.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[8.000e+00, 0.000e+00, 1.100e+01]],
#
#        [[8.000e+00, 0.000e+00, 1.000e+01]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 6.000e+00]],
#
#        [[1.932e+03, 1.500e+01, 1.180e+02]],
#
#        [[1.931e+03, 1.500e+01, 1.110e+02]],
#
#        [[1.770e+02, 0.000e+00, 3.700e+01]],
#
#        [[7.100e+01, 0.000e+00, 0.000e+00]],
#
#        [[1.060e+02, 0.000e+00, 3.700e+01]],
#
#        [[1.754e+03, 1.500e+01, 7.400e+01]],
#
#        [[1.414e+03, 1.500e+01, 6.100e+01]],
#
#        [[4.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[1.410e+03, 1.500e+01, 6.100e+01]],
#
#        [[3.400e+02, 0.000e+00, 1.300e+01]],
#
#        [[3.380e+02, 0.000e+00, 1.300e+01]],
#
#        [[2.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 7.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 6.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[6.300e+01, 2.190e+02, 9.930e+02]],
#
#        [[6.300e+01, 5.400e+01, 9.040e+02]],
#
#        [[6.000e+01, 4.700e+01, 3.250e+02]],
#
#        [[0.000e+00, 1.600e+01, 2.200e+01]],
#
#        [[0.000e+00, 1.600e+01, 1.600e+01]],
#
#        [[0.000e+00, 1.200e+01, 1.500e+01]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 1.100e+01, 1.500e+01]],
#
#        [[0.000e+00, 1.100e+01, 1.400e+01]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 4.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 6.000e+00]],
#
#        [[6.000e+01, 3.100e+01, 3.030e+02]],
#
#        [[5.800e+01, 9.000e+00, 1.880e+02]],
#
#        [[8.000e+00, 7.000e+00, 1.260e+02]],
#
#        [[8.000e+00, 6.000e+00, 1.260e+02]],
#
#        [[8.000e+00, 6.000e+00, 8.500e+01]],
#
#        [[8.000e+00, 4.000e+00, 8.400e+01]],
#
#        [[0.000e+00, 0.000e+00, 2.300e+01]],
#
#        [[8.000e+00, 4.000e+00, 6.100e+01]],
#
#        [[3.000e+00, 2.000e+00, 9.000e+00]],
#
#        [[0.000e+00, 2.000e+00, 9.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 9.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 3.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 6.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[3.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[5.000e+00, 2.000e+00, 5.200e+01]],
#
#        [[4.000e+00, 1.000e+00, 4.900e+01]],
#
#        [[1.000e+00, 0.000e+00, 2.700e+01]],
#
#        [[0.000e+00, 0.000e+00, 2.300e+01]],
#
#        [[1.000e+00, 0.000e+00, 4.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 4.000e+00]],
#
#        [[3.000e+00, 1.000e+00, 2.200e+01]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[3.000e+00, 0.000e+00, 2.200e+01]],
#
#        [[3.000e+00, 0.000e+00, 1.200e+01]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+01]],
#
#        [[1.000e+00, 1.000e+00, 3.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 3.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 2.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 2.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 4.100e+01]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[5.000e+01, 2.000e+00, 6.200e+01]],
#
#        [[5.000e+01, 0.000e+00, 4.700e+01]],
#
#        [[5.000e+00, 0.000e+00, 1.700e+01]],
#
#        [[1.000e+00, 0.000e+00, 1.500e+01]],
#
#        [[0.000e+00, 0.000e+00, 6.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 9.000e+00]],
#
#        [[4.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[4.500e+01, 0.000e+00, 3.000e+01]],
#
#        [[9.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[3.600e+01, 0.000e+00, 3.000e+01]],
#
#        [[0.000e+00, 0.000e+00, 8.000e+00]],
#
#        [[3.600e+01, 0.000e+00, 2.200e+01]],
#
#        [[3.600e+01, 0.000e+00, 2.100e+01]],
#
#        [[8.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[7.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[2.800e+01, 0.000e+00, 1.900e+01]],
#
#        [[1.000e+00, 0.000e+00, 5.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 3.000e+00]],
#
#        [[2.700e+01, 0.000e+00, 1.400e+01]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 2.000e+00, 1.500e+01]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 1.500e+01]],
#
#        [[0.000e+00, 0.000e+00, 1.200e+01]],
#
#        [[0.000e+00, 1.000e+00, 3.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 3.000e+00]],
#
#        [[2.000e+00, 2.200e+01, 1.150e+02]],
#
#        [[0.000e+00, 1.800e+01, 4.200e+01]],
#
#        [[0.000e+00, 0.000e+00, 9.000e+00]],
#
#        [[0.000e+00, 1.800e+01, 3.300e+01]],
#
#        [[2.000e+00, 4.000e+00, 7.300e+01]],
#
#        [[2.000e+00, 1.000e+00, 7.200e+01]],
#
#        [[2.000e+00, 0.000e+00, 7.000e+01]],
#
#        [[0.000e+00, 0.000e+00, 3.000e+01]],
#
#        [[2.000e+00, 0.000e+00, 4.000e+01]],
#
#        [[2.000e+00, 0.000e+00, 3.400e+01]],
#
#        [[0.000e+00, 0.000e+00, 3.000e+00]],
#
#        [[2.000e+00, 0.000e+00, 3.100e+01]],
#
#        [[2.000e+00, 0.000e+00, 3.000e+01]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 6.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 3.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 3.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[3.000e+00, 7.000e+00, 5.790e+02]],
#
#        [[3.000e+00, 0.000e+00, 3.900e+01]],
#
#        [[0.000e+00, 0.000e+00, 3.500e+01]],
#
#        [[3.000e+00, 0.000e+00, 4.000e+00]],
#
#        [[0.000e+00, 7.000e+00, 5.400e+02]],
#
#        [[0.000e+00, 0.000e+00, 3.400e+02]],
#
#        [[0.000e+00, 7.000e+00, 2.000e+02]],
#
#        [[0.000e+00, 1.650e+02, 8.900e+01]],
#
#        [[0.000e+00, 8.800e+01, 7.700e+01]],
#
#        [[0.000e+00, 7.700e+01, 1.200e+01]],
#
#        [[0.000e+00, 3.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 7.400e+01, 1.200e+01]]])

# %%
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D

# %%
# switch to interactive matplotlib
# %matplotlib qt
# %pylab qt

# switch back to inline mode
# %matplotlib inline

# %% [markdown]
# ## 3D scatter

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection="3d")
colors = y.map({"LOW": "green", "MEDIUM": "yellow", "HIGH": "red"})
ax.scatter(X["%HIss"], X["%Hic"], X["%HIins"], alpha=0.5, c=colors)
ax.set_xlabel("%HIss")
ax.set_ylabel("%Hic")
ax.set_zlabel("%HIins")
# Out:
# Text(0.5, 0, '%HIins')

# %%
predicted = model.predict(X_test)
predicted
# Out:
# array(['HIGH', 'LOW', 'LOW', 'MEDIUM', 'MEDIUM', 'LOW', 'LOW', 'HIGH',
#        'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'LOW', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'LOW', 'LOW', 'MEDIUM',
#        'LOW', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'LOW', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'LOW', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'LOW', 'MEDIUM', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'LOW', 'LOW', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'LOW', 'LOW', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM',
#        'LOW', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'LOW', 'HIGH', 'MEDIUM',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'LOW', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'LOW', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'LOW', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'LOW', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'LOW', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'LOW', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'LOW', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'LOW', 'HIGH', 'HIGH',
#        'HIGH', 'LOW', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'LOW',
#        'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'LOW', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'LOW', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'MEDIUM', 'MEDIUM', 'LOW', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'HIGH',
#        'HIGH', 'MEDIUM', 'LOW', 'HIGH', 'LOW', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'HIGH', 'MEDIUM', 'HIGH',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'LOW', 'HIGH', 'MEDIUM',
#        'MEDIUM', 'MEDIUM', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'LOW', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'LOW', 'MEDIUM', 'LOW',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM', 'LOW', 'HIGH', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'HIGH',
#        'HIGH', 'HIGH', 'LOW', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'LOW', 'HIGH', 'LOW', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'LOW', 'LOW', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'HIGH',
#        'MEDIUM', 'LOW', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'MEDIUM',
#        'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'LOW', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'MEDIUM', 'LOW', 'MEDIUM',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'MEDIUM',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM',
#        'LOW', 'MEDIUM', 'HIGH', 'LOW', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'MEDIUM', 'HIGH',
#        'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM', 'MEDIUM', 'HIGH',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'MEDIUM',
#        'HIGH', 'HIGH', 'LOW', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'LOW', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'LOW', 'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'MEDIUM', 'LOW', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'MEDIUM', 'MEDIUM', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM', 'LOW', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'LOW', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'LOW', 'HIGH',
#        'HIGH', 'LOW', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'LOW', 'MEDIUM', 'HIGH', 'LOW', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'LOW', 'LOW', 'HIGH', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM',
#        'LOW', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'LOW', 'MEDIUM', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'MEDIUM', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'LOW', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'LOW', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'LOW', 'LOW', 'HIGH', 'HIGH', 'LOW', 'HIGH', 'HIGH'], dtype=object)

# %%
pd.crosstab(y_test, predicted)
# Out:
# col_0          HIGH  LOW  MEDIUM
# %Hiline_level
# HIGH            524    0       8
# LOW               5   48      17
# MEDIUM           41   29     250
