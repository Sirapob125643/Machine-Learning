# %% [markdown]
# ## Classification Tree

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %config InlineBackend.figure_format = 'svg'

# %%
print(f"pandas  version: {pd.__version__}")
print(f"numpy   version: {np.__version__}")
print(f"seaborn version: {sns.__version__}")
# Out:
# pandas  version: 1.4.4
# numpy   version: 1.21.5
# seaborn version: 0.12.0

# %%
df = pd.read_excel("Real_score_new1.xlsx")
df.sample(50)
# Out:
#       towerid  conductor_visual   Wi_con_vir  conductor_zinc   Wi_con_zin  \
# 1473     1474                 2           20               0           20
# 336       337                 3           20               0           20
# 4281     4282                 2           20               0           20
# 1612     1613                 3           20               0           20
# 1715     1716                 5           20               5           20
# 3061     3062                 3           20               0           20
# 654       655                 2           20               0           20
# 593       594                 2           20               0           20
# 163       164                 3           20               0           20
# 184       185                 3           20               0           20
# 3981     3982                 0           20               0           20
# 2324     2325                 3           20               0           20
# 3199     3200                 4           20               0           20
# 3649     3650                 3           20               0           20
# 409       410                 3           20               0           20
# 994       995                 3           20               0           20
# 1395     1396                 3           20               0           20
# 3458     3459                 2           20               0           20
# 2487     2488                 3           20               0           20
# 314       315                 3           20               0           20
# 629       630                 2           20               0           20
# 1452     1453                 2           20               0           20
# 881       882                 3           20               0           20
# 2353     2354                 3           20               0           20
# 2237     2238                 3           20               0           20
# 199       200                 3           20               0           20
# 2992     2993                 2           20               0           20
# 4476     4477                 2           20               0           20
# 3830     3831                 3           20               0           20
# 3769     3770                 3           20               0           20
# 76         77                 3           20               0           20
# 4406     4407                 2           20               0           20
# 2929     2930                 3           20               0           20
# 663       664                 2           20               0           20
# 4449     4450                 2           20               0           20
# 382       383                 3           20               0           20
# 194       195                 3           20               0           20
# 781       782                 3           20               0           20
# 1732     1733                 5           20               5           20
# 3709     3710                 3           20               0           20
# 2514     2515                 3           20               0           20
# 1038     1039                 3           20               0           20
# 2878     2879                 0           20               0           20
# 3930     3931                 0           20               0           20
# 307       308                 3           20               0           20
# 4400     4401                 2           20               0           20
# 1538     1539                 3           20               0           20
# 1610     1611                 3           20               0           20
# 4324     4325                 2           20               0           20
# 416       417                 3           20               0           20
#
#       conductor_tensile   Wi_con_ten  conductor_ductility   Wi_con_duc  \
# 1473                  0           20                    0           20
# 336                   0           20                    0           20
# 4281                  0           20                    0           20
# 1612                  0           20                    0           20
# 1715                  4           20                    0           20
# 3061                  0           20                    0           20
# 654                   0           20                    0           20
# 593                   0           20                    0           20
# 163                   0           20                    0           20
# 184                   0           20                    0           20
# 3981                  0           20                    0           20
# 2324                  0           20                    0           20
# 3199                  0           20                    0           20
# 3649                  0           20                    0           20
# 409                   0           20                    0           20
# 994                   0           20                    0           20
# 1395                  0           20                    0           20
# 3458                  0           20                    0           20
# 2487                  0           20                    0           20
# 314                   0           20                    0           20
# 629                   0           20                    0           20
# 1452                  0           20                    0           20
# 881                   0           20                    0           20
# 2353                  0           20                    0           20
# 2237                  0           20                    0           20
# 199                   0           20                    0           20
# 2992                  0           20                    0           20
# 4476                  0           20                    0           20
# 3830                  0           20                    0           20
# 3769                  0           20                    0           20
# 76                    0           20                    0           20
# 4406                  0           20                    0           20
# 2929                  0           20                    0           20
# 663                   0           20                    0           20
# 4449                  0           20                    0           20
# 382                   0           20                    0           20
# 194                   0           20                    0           20
# 781                   0           20                    0           20
# 1732                  4           20                    0           20
# 3709                  0           20                    0           20
# 2514                  0           20                    0           20
# 1038                  0           20                    0           20
# 2878                  0           20                    0           20
# 3930                  0           20                    0           20
# 307                   0           20                    0           20
# 4400                  0           20                    0           20
# 1538                  0           20                    0           20
# 1610                  0           20                    0           20
# 4324                  0           20                    0           20
# 416                   0           20                    0           20
#
#       conductor_tensileaac  ...   %HImaxCon   %HImaxCA  %HImaxINS  %HImaxSS  \
# 1473                     0  ...   20.000000   0.000000   0.000000         0
# 336                      0  ...   20.000000   9.090909  50.000000         0
# 4281                     0  ...   56.000000  52.727273  85.000000        88
# 1612                     0  ...   20.000000   9.090909  50.000000        30
# 1715                     0  ...   56.000000  16.363636  65.000000        82
# 3061                     0  ...   33.333333  30.303030  91.666667        60
# 654                      0  ...   20.000000   9.090909  50.000000         0
# 593                      0  ...   20.000000  18.181818  62.500000        40
# 163                      0  ...   20.000000   9.090909  50.000000         0
# 184                      0  ...   20.000000   9.090909  50.000000         0
# 3981                     0  ...   20.000000   9.090909  75.000000        30
# 2324                     0  ...   20.000000   9.090909  50.000000         0
# 3199                     0  ...   20.000000  18.181818  70.000000        88
# 3649                     0  ...   20.000000   9.090909  50.000000        50
# 409                      0  ...   20.000000   9.090909  50.000000         0
# 994                      0  ...   20.000000   9.090909  50.000000         0
# 1395                     0  ...   20.000000   9.090909  50.000000         0
# 3458                     0  ...   20.000000  18.181818  50.000000         0
# 2487                     0  ...   20.000000   9.090909  50.000000         0
# 314                      0  ...   20.000000   9.090909  50.000000         0
# 629                      0  ...   20.000000   9.090909   0.000000         0
# 1452                     0  ...   20.000000   0.000000   0.000000         0
# 881                      0  ...   20.000000   9.090909  50.000000         0
# 2353                     0  ...   20.000000  18.181818  75.000000         0
# 2237                     0  ...   20.000000   9.090909  50.000000         0
# 199                      0  ...   20.000000   9.090909  50.000000         0
# 2992                     0  ...   33.333333  30.303030  91.666667        60
# 4476                     0  ...   20.000000  18.181818  50.000000         0
# 3830                     0  ...   20.000000   9.090909  50.000000        50
# 3769                     0  ...   20.000000   9.090909  50.000000        40
# 76                       0  ...   20.000000   9.090909  50.000000         0
# 4406                     0  ...   20.000000  18.181818  50.000000         0
# 2929                     0  ...   88.000000  36.363636  95.000000        50
# 663                      0  ...   20.000000   9.090909  50.000000         0
# 4449                     0  ...   20.000000  18.181818  50.000000         0
# 382                      0  ...   20.000000   9.090909  50.000000         0
# 194                      0  ...   20.000000   9.090909  50.000000         0
# 781                      0  ...   20.000000   9.090909  50.000000         0
# 1732                     0  ...   56.000000  16.363636  65.000000        82
# 3709                     0  ...   20.000000   9.090909  50.000000        40
# 2514                     0  ...   20.000000   9.090909  50.000000         0
# 1038                     0  ...   20.000000   9.090909  50.000000         0
# 2878                     0  ...  100.000000  80.000000  95.000000        60
# 3930                     0  ...   20.000000   9.090909  50.000000        40
# 307                      0  ...   20.000000   9.090909  50.000000         0
# 4400                     0  ...   20.000000  18.181818  50.000000         0
# 1538                     0  ...   20.000000   9.090909  50.000000         0
# 1610                     0  ...   20.000000   9.090909  50.000000        30
# 4324                     0  ...   20.000000  18.181818  75.000000        50
# 416                      0  ...   20.000000   9.090909  50.000000         0
#
#       %HImaxFou   %HImaxLP  %HImaxTA  %HImaxROW    %HIline  %Hiline_level
# 1473       0.00   0.000000         0          0   5.129700           HIGH
# 336        0.00  25.000000         0          0  14.856745           HIGH
# 4281      90.00  75.000000        90        100  71.917564            LOW
# 1612      50.00  25.000000        50          0  30.580745         MEDIUM
# 1715      82.50  65.000000        90        100  64.716082         MEDIUM
# 3061      50.00  50.000000        75         50  49.080852         MEDIUM
# 654        0.00  25.000000         0          0  14.856745           HIGH
# 593       50.00  33.333333       100         50  37.160791         MEDIUM
# 163        0.00  25.000000         0          0  14.856745           HIGH
# 184        0.00  25.000000         0          0  14.856745           HIGH
# 3981      37.50  29.166667       100          0  33.071995         MEDIUM
# 2324       0.00  25.000000         0          0  14.856745           HIGH
# 3199      90.00  75.000000        90        100  60.228691         MEDIUM
# 3649      50.00  25.000000       100          0  35.226745         MEDIUM
# 409        0.00  25.000000         0          0  14.856745           HIGH
# 994        0.00  25.000000         0          0  14.856745           HIGH
# 1395       0.00  25.000000         0          0  14.856745           HIGH
# 3458       0.00  25.000000         0          0  15.121291           HIGH
# 2487       0.00  25.000000         0          0  14.856745           HIGH
# 314        0.00  25.000000         0          0  14.856745           HIGH
# 629        0.00  25.000000         0          0   9.616745           HIGH
# 1452       0.00   0.000000         0          0   5.129700           HIGH
# 881        0.00  25.000000         0          0  14.856745           HIGH
# 2353       0.00  25.000000         0          0  17.741291           HIGH
# 2237       0.00  25.000000         0          0  14.856745           HIGH
# 199        0.00  25.000000         0          0  14.856745           HIGH
# 2992     100.00  50.000000       100        100  59.885852         MEDIUM
# 4476       0.00  25.000000         0          0  15.121291           HIGH
# 3830      37.50  25.000000       100          0  32.844245         MEDIUM
# 3769      50.00  25.000000       100          0  33.678745         MEDIUM
# 76         0.00  25.000000         0          0  14.856745           HIGH
# 4406       0.00  25.000000         0          0  15.121291           HIGH
# 2929      50.00  56.250000       100         50  63.725307         MEDIUM
# 663        0.00  25.000000         0          0  14.856745           HIGH
# 4449       0.00  25.000000         0          0  15.121291           HIGH
# 382        0.00  25.000000         0          0  14.856745           HIGH
# 194        0.00  25.000000         0          0  14.856745           HIGH
# 781        0.00  25.000000         0          0  14.856745           HIGH
# 1732      82.50  65.000000        90        100  64.716082         MEDIUM
# 3709      37.50  31.250000       100          0  32.351870         MEDIUM
# 2514       0.00  25.000000         0          0  14.856745           HIGH
# 1038       0.00  25.000000         0          0  14.856745           HIGH
# 2878      62.50  57.500000        50        100  71.123950            LOW
# 3930      37.50  25.000000       100          0  31.296245         MEDIUM
# 307        0.00  25.000000         0          0  14.856745           HIGH
# 4400       0.00  25.000000         0          0  15.121291           HIGH
# 1538       0.00  25.000000         0          0  14.856745           HIGH
# 1610      50.00  25.000000        50          0  30.580745         MEDIUM
# 4324      31.25  25.000000       100          0  34.537541         MEDIUM
# 416        0.00  25.000000         0          0  14.856745           HIGH
#
# [50 rows x 140 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4608 entries, 0 to 4607
# Columns: 140 entries, towerid to %Hiline_level
# dtypes: float64(48), int64(91), object(1)
# memory usage: 4.9+ MB

# %%
df.columns
# Out:
# Index(['towerid', 'conductor_visual', ' Wi_con_vir', 'conductor_zinc',
#        ' Wi_con_zin', 'conductor_tensile', ' Wi_con_ten',
#        'conductor_ductility', ' Wi_con_duc', 'conductor_tensileaac',
#        ...
#        '%HImaxCon', '%HImaxCA', '%HImaxINS', '%HImaxSS', '%HImaxFou',
#        '%HImaxLP', '%HImaxTA', '%HImaxROW', '%HIline', '%Hiline_level'],
#       dtype='object', length=140)

# %% [markdown]
# ## Draw Decision Tree

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import (
    confusion_matrix,
    plot_confusion_matrix,
    classification_report,
    accuracy_score,
    precision_score,
    recall_score,
    precision_recall_fscore_support,
    f1_score,
)

# %%
df.columns
# Out:
# Index(['towerid', 'conductor_visual', ' Wi_con_vir', 'conductor_zinc',
#        ' Wi_con_zin', 'conductor_tensile', ' Wi_con_ten',
#        'conductor_ductility', ' Wi_con_duc', 'conductor_tensileaac',
#        ...
#        '%HImaxCon', '%HImaxCA', '%HImaxINS', '%HImaxSS', '%HImaxFou',
#        '%HImaxLP', '%HImaxTA', '%HImaxROW', '%HIline', '%Hiline_level'],
#       dtype='object', length=140)

# %%
cols = [    "conductor_visual","conductor_zinc","conductor_tensile",     "conductor_ductility" ,"conductor_tensileaac","Con-Smax",    "conacc_visual","conacc_spacer","conacc_clamp","conacc_sc","conacc_damping","conacc_fating","deadend_resistance","deadend_thermography","clamp_thermography","joint_resistance","joint_thermography","CA-Smax",    "insulator_thermography","insulator_assester","insulator_visual","insulator_fitting","INS-Smax",    "visual_zinc","visual_corrosion","visual_member","visual_nut","visual_nutstub","visual_no","tower_color","tower_broke","anchor_color","anchor_corrosion","SS-Smax",    "concrete_crack","concrete_gliding","concrete_mainleg","concrete_flood","concrete_color","stub_zinc","stub_corrosion","found-Smax",    "protection_opgw","protection_zinc","protection_tensile","protection_overhead","protection_marker","ground_loss","ground_loose","ground_oxide","ground_oxide","Lp-Smax",    "danger_color","danger_broke","phase_color","phase_broke","TA-Smax",    "row_district","row_building","ROW-Smax",  ]

# %%
X = df[cols]  # features
y = df["%Hiline_level"]  # label

# %%
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=test_size, stratify=y, random_state=7
)

# %%
#เนื่องจากค่าตัวแปรมีทั้งหลักหน่วย สิบ ร้อย พัน,ค่าที่สูง dominate ค่าน้อย จึงต้องทำ
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# Fit only to the trainning data
scaler.fit(X_train)

#Now apply the transformations to the data:
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-0.79569493, -0.21967112, -0.2204804 , ..., -0.38416526,
#         -0.37926309, -0.3848424 ],
#        [ 1.17073585, -0.21967112, -0.2204804 , ...,  2.64025412,
#          2.64401493,  2.63973989],
#        [-2.7621257 , -0.21967112, -0.2204804 , ..., -0.38416526,
#         -0.37926309, -0.3848424 ],
#        ...,
#        [ 0.18752046, -0.21967112, -0.2204804 , ..., -0.38416526,
#         -0.37926309, -0.3848424 ],
#        [-0.79569493, -0.21967112, -0.2204804 , ..., -0.38416526,
#         -0.37926309, -0.3848424 ],
#        [-2.7621257 , -0.21967112, -0.2204804 , ..., -0.38416526,
#         -0.37926309, -0.3848424 ]])

# %%
X_train = pd.DataFrame(X_train, columns = X.columns)

X_test = pd.DataFrame(X_test, columns=X.columns)

# %%
model = DecisionTreeClassifier(criterion="gini")  # gini is a default
# model=DecisionTreeClassifier(criterion='entropy')

model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
X_train.columns
# Out:
# Index(['conductor_visual', 'conductor_zinc', 'conductor_tensile',
#        'conductor_ductility', 'conductor_tensileaac', 'Con-Smax',
#        'conacc_visual', 'conacc_spacer', 'conacc_clamp', 'conacc_sc',
#        'conacc_damping', 'conacc_fating', 'deadend_resistance',
#        'deadend_thermography', 'clamp_thermography', 'joint_resistance',
#        'joint_thermography', 'CA-Smax', 'insulator_thermography',
#        'insulator_assester', 'insulator_visual', 'insulator_fitting',
#        'INS-Smax', 'visual_zinc', 'visual_corrosion', 'visual_member',
#        'visual_nut', 'visual_nutstub', 'visual_no', 'tower_color',
#        'tower_broke', 'anchor_color', 'anchor_corrosion', 'SS-Smax',
#        'concrete_crack', 'concrete_gliding', 'concrete_mainleg',
#        'concrete_flood', 'concrete_color', 'stub_zinc', 'stub_corrosion',
#        'found-Smax', 'protection_opgw', 'protection_zinc',
#        'protection_tensile', 'protection_overhead', 'protection_marker',
#        'ground_loss', 'ground_loose', 'ground_oxide', 'ground_oxide',
#        'Lp-Smax', 'danger_color', 'danger_broke', 'phase_color', 'phase_broke',
#        'TA-Smax', 'row_district', 'row_building', 'ROW-Smax'],
#       dtype='object')

# %%
model.feature_importances_
# Out:
# array([4.77687362e-02, 6.63585960e-04, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.33547521e-01, 1.91347553e-03, 8.10314385e-04,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 5.60686143e-02,
#        0.00000000e+00, 3.07850946e-02, 2.56438015e-03, 3.45233835e-03,
#        1.43459930e-03, 1.06573746e-02, 7.88035240e-03, 1.46356222e-02,
#        1.27432838e-03, 9.26071647e-03, 3.15214786e-03, 1.13185033e-03,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 5.42210166e-04,
#        7.81161504e-04, 6.12521626e-01, 0.00000000e+00, 7.99600473e-04,
#        6.63585960e-04, 5.81336506e-03, 1.71862061e-03, 4.51607111e-04,
#        1.64705438e-03, 6.73822368e-03, 3.27614991e-03, 6.46014369e-04,
#        0.00000000e+00, 1.77917599e-02, 0.00000000e+00, 3.06454389e-04,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 4.79535796e-03,
#        0.00000000e+00, 0.00000000e+00, 7.30006479e-03, 5.30387624e-03,
#        0.00000000e+00, 1.85171013e-03, 5.05054853e-05, 0.00000000e+00])

# %%
fs = pd.Series(model.feature_importances_, index=X_train.columns).sort_values(
    ascending=False
)
fs
# Out:
# SS-Smax                   0.612522
# Con-Smax                  0.133548
# joint_resistance          0.056069
# conductor_visual          0.047769
# CA-Smax                   0.030785
# protection_overhead       0.017792
# visual_zinc               0.014636
# insulator_fitting         0.010657
# visual_member             0.009261
# INS-Smax                  0.007880
# phase_color               0.007300
# found-Smax                0.006738
# concrete_flood            0.005813
# phase_broke               0.005304
# Lp-Smax                   0.004795
# insulator_assester        0.003452
# protection_opgw           0.003276
# visual_nut                0.003152
# insulator_thermography    0.002564
# conacc_visual             0.001913
# row_district              0.001852
# concrete_color            0.001719
# stub_corrosion            0.001647
# insulator_visual          0.001435
# visual_corrosion          0.001274
# visual_nutstub            0.001132
# conacc_spacer             0.000810
# concrete_gliding          0.000800
# anchor_corrosion          0.000781
# concrete_mainleg          0.000664
# conductor_zinc            0.000664
# protection_zinc           0.000646
# anchor_color              0.000542
# stub_zinc                 0.000452
# ground_loss               0.000306
# row_building              0.000051
# protection_marker         0.000000
# danger_color              0.000000
# TA-Smax                   0.000000
# protection_tensile        0.000000
# ground_loose              0.000000
# ground_oxide              0.000000
# ground_oxide              0.000000
# danger_broke              0.000000
# tower_broke               0.000000
# concrete_crack            0.000000
# tower_color               0.000000
# visual_no                 0.000000
# joint_thermography        0.000000
# clamp_thermography        0.000000
# deadend_thermography      0.000000
# deadend_resistance        0.000000
# conacc_fating             0.000000
# conacc_damping            0.000000
# conacc_sc                 0.000000
# conacc_clamp              0.000000
# conductor_tensileaac      0.000000
# conductor_ductility       0.000000
# conductor_tensile         0.000000
# ROW-Smax                  0.000000
# dtype: float64

# %%
y_train.value_counts()
# Out:
# HIGH      2126
# MEDIUM    1280
# LOW        280
# Name: %Hiline_level, dtype: int64

# %% [markdown]
# ## tree diagram

# %%
clf = DecisionTreeClassifier(criterion="gini")
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
clf.__dict__
# Out:
# {'criterion': 'gini',
#  'splitter': 'best',
#  'max_depth': None,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'min_weight_fraction_leaf': 0.0,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'random_state': None,
#  'min_impurity_decrease': 0.0,
#  'class_weight': None,
#  'ccp_alpha': 0.0,
#  'feature_names_in_': array(['conductor_visual', 'conductor_zinc', 'conductor_tensile',
#         'conductor_ductility', 'conductor_tensileaac', 'Con-Smax',
#         'conacc_visual', 'conacc_spacer', 'conacc_clamp', 'conacc_sc',
#         'conacc_damping', 'conacc_fating', 'deadend_resistance',
#         'deadend_thermography', 'clamp_thermography', 'joint_resistance',
#         'joint_thermography', 'CA-Smax', 'insulator_thermography',
#         'insulator_assester', 'insulator_visual', 'insulator_fitting',
#         'INS-Smax', 'visual_zinc', 'visual_corrosion', 'visual_member',
#         'visual_nut', 'visual_nutstub', 'visual_no', 'tower_color',
#         'tower_broke', 'anchor_color', 'anchor_corrosion', 'SS-Smax',
#         'concrete_crack', 'concrete_gliding', 'concrete_mainleg',
#         'concrete_flood', 'concrete_color', 'stub_zinc', 'stub_corrosion',
#         'found-Smax', 'protection_opgw', 'protection_zinc',
#         'protection_tensile', 'protection_overhead', 'protection_marker',
#         'ground_loss', 'ground_loose', 'ground_oxide', 'ground_oxide',
#         'Lp-Smax', 'danger_color', 'danger_broke', 'phase_color',
#         'phase_broke', 'TA-Smax', 'row_district', 'row_building',
#         'ROW-Smax'], dtype=object),
#  'n_features_in_': 60,
#  'n_outputs_': 1,
#  'classes_': array(['HIGH', 'LOW', 'MEDIUM'], dtype=object),
#  'n_classes_': 3,
#  'max_features_': 60,
#  'tree_': <sklearn.tree._tree.Tree at 0x27a02112b90>}

# %%
clf.__dict__["tree_"]

# %%
type(clf)
# Out:
# sklearn.tree._classes.DecisionTreeClassifier

# %%
clf.__dict__["classes_"]
# Out:
# array(['HIGH', 'LOW', 'MEDIUM'], dtype=object)

# %%
from sklearn.tree import export_graphviz
from graphviz import Digraph, Source


def view_tree(model, X, save_tree_img=False):
    estimators = clf
    dot_graph = export_graphviz(
        estimators,
        feature_names=X.columns,
        class_names=model.__dict__["classes_"],
        rounded=True,
        proportion=False,
        precision=2,
        filled=True,
    )
    #     with open(f'tree{tree_index}.dot') as f:
    #         dot_graph = f.read()
    g = Source(dot_graph)
    if save_tree_img:
        g.render(f"tree", format="png", view=False, cleanup=True)
    return g

# %%
view_tree(clf, X_test, save_tree_img=False)

# %%
cm = confusion_matrix(y_test, model.predict(X_test))
cm
# Out:
# array([[527,   0,   5],
#        [  5,  49,  16],
#        [ 33,  29, 258]], dtype=int64)

# %%
print(classification_report(y, model.predict(X)))
# Out:
#               precision    recall  f1-score   support
#
#         HIGH       0.00      0.00      0.00      2658
#          LOW       1.00      0.00      0.01       350
#       MEDIUM       0.35      1.00      0.52      1600
#
#     accuracy                           0.35      4608
#    macro avg       0.45      0.33      0.17      4608
# weighted avg       0.20      0.35      0.18      4608
# C:\Users\bedm2\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\bedm2\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\bedm2\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
model.tree_.impurity  # gini
# Out:
# array([0.54096847, 0.2530332 , 0.4243667 , 0.45593262, 0.4608    ,
#        0.46400952, 0.46560064, 0.        , 0.        , 0.        ,
#        0.0768    , 0.        , 0.5       , 0.        , 0.        ,
#        0.15966535, 0.45184304, 0.10493827, 0.0229854 , 0.        ,
#        0.        , 0.        , 0.45209751, 0.49546485, 0.49256395,
#        0.        , 0.36281179, 0.        , 0.38132807, 0.3944485 ,
#        0.        , 0.375     , 0.32      , 0.        , 0.39111111,
#        0.4296875 , 0.44444444, 0.45918367, 0.47337278, 0.        ,
#        0.        , 0.        , 0.        , 0.1228849 , 0.09952988,
#        0.09692121, 0.09192305, 0.09100427, 0.08820657, 0.        ,
#        0.0904964 , 0.09501002, 0.        , 0.09549955, 0.09562272,
#        0.        , 0.09568443, 0.        , 0.09574621, 0.        ,
#        0.07113572, 0.        , 0.07172355, 0.16757396, 0.23111111,
#        0.20975057, 0.        , 0.21415824, 0.44444444, 0.        ,
#        0.        , 0.5       , 0.375     , 0.        , 0.24489796,
#        0.        , 0.        , 0.42438272, 0.41925059, 0.4260355 ,
#        0.42240588, 0.48      , 0.        , 0.        , 0.36148927,
#        0.29964463, 0.19093347, 0.37090627, 0.13165509, 0.33364839,
#        0.28911565, 0.47645429, 0.3203125 , 0.49382716, 0.40816327,
#        0.        , 0.27777778, 0.375     , 0.44444444, 0.        ,
#        0.        , 0.5       , 0.        , 0.        , 0.        ,
#        0.        , 0.0831758 , 0.21875   , 0.        , 0.27777778,
#        0.        , 0.5       , 0.44444444, 0.5       , 0.        ,
#        0.        , 0.02019992, 0.        , 0.32      , 0.        ,
#        0.        , 0.51268001, 0.53418493, 0.45619075, 0.375     ,
#        0.        , 0.        , 0.40595041, 0.38408779, 0.37023852,
#        0.        , 0.41632231, 0.40237966, 0.41403926, 0.        ,
#        0.42      , 0.4260355 , 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.07986111, 0.5       , 0.        ,
#        0.        , 0.        , 0.32      , 0.        , 0.4567474 ,
#        0.08815496, 0.39912716, 0.22926308, 0.48      , 0.        ,
#        0.        , 0.15277778, 0.375     , 0.        , 0.48979592,
#        0.5       , 0.        , 0.        , 0.51234568, 0.39111111,
#        0.26035503, 0.44444444, 0.        , 0.        , 0.44444444,
#        0.        , 0.        , 0.03683794, 0.03034692, 0.        ,
#        0.08166932, 0.5       , 0.44444444, 0.        , 0.06534575,
#        0.        , 0.49990081, 0.29752066, 0.19753086, 0.1171875 ,
#        0.375     , 0.        , 0.5       , 0.        , 0.        ,
#        0.5       , 0.        , 0.        , 0.4983416 , 0.49763444,
#        0.44444444, 0.41522491, 0.45918367, 0.        , 0.        ,
#        0.49916214, 0.        , 0.49738714, 0.49777778, 0.        ,
#        0.        , 0.23553719, 0.        , 0.2401298 ])

# %%
model.tree_.value
# Out:
# array([[[2.126e+03, 2.800e+02, 1.280e+03]],
#
#        [[2.063e+03, 6.100e+01, 2.870e+02]],
#
#        [[1.000e+00, 4.500e+01, 1.070e+02]],
#
#        [[0.000e+00, 4.500e+01, 8.300e+01]],
#
#        [[0.000e+00, 4.500e+01, 8.000e+01]],
#
#        [[0.000e+00, 4.500e+01, 7.800e+01]],
#
#        [[0.000e+00, 4.500e+01, 7.700e+01]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 3.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 2.400e+01]],
#
#        [[0.000e+00, 0.000e+00, 2.300e+01]],
#
#        [[1.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[2.062e+03, 1.600e+01, 1.800e+02]],
#
#        [[1.140e+02, 0.000e+00, 6.000e+01]],
#
#        [[8.500e+01, 0.000e+00, 5.000e+00]],
#
#        [[8.500e+01, 0.000e+00, 1.000e+00]],
#
#        [[8.500e+01, 0.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 4.000e+00]],
#
#        [[2.900e+01, 0.000e+00, 5.500e+01]],
#
#        [[1.900e+01, 0.000e+00, 2.300e+01]],
#
#        [[1.800e+01, 0.000e+00, 2.300e+01]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[1.000e+01, 0.000e+00, 3.200e+01]],
#
#        [[0.000e+00, 0.000e+00, 3.000e+00]],
#
#        [[1.000e+01, 0.000e+00, 2.900e+01]],
#
#        [[1.000e+01, 0.000e+00, 2.700e+01]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[9.000e+00, 0.000e+00, 2.700e+01]],
#
#        [[4.000e+00, 0.000e+00, 1.600e+01]],
#
#        [[0.000e+00, 0.000e+00, 5.000e+00]],
#
#        [[4.000e+00, 0.000e+00, 1.100e+01]],
#
#        [[5.000e+00, 0.000e+00, 1.100e+01]],
#
#        [[5.000e+00, 0.000e+00, 1.000e+01]],
#
#        [[5.000e+00, 0.000e+00, 9.000e+00]],
#
#        [[5.000e+00, 0.000e+00, 8.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[1.948e+03, 1.600e+01, 1.200e+02]],
#
#        [[1.873e+03, 1.600e+01, 8.700e+01]],
#
#        [[1.873e+03, 1.600e+01, 8.400e+01]],
#
#        [[1.867e+03, 1.600e+01, 7.800e+01]],
#
#        [[1.867e+03, 1.500e+01, 7.800e+01]],
#
#        [[1.808e+03, 1.500e+01, 7.200e+01]],
#
#        [[5.000e+01, 0.000e+00, 0.000e+00]],
#
#        [[1.758e+03, 1.500e+01, 7.200e+01]],
#
#        [[1.419e+03, 1.500e+01, 5.900e+01]],
#
#        [[8.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[1.411e+03, 1.500e+01, 5.900e+01]],
#
#        [[1.409e+03, 1.500e+01, 5.900e+01]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[1.408e+03, 1.500e+01, 5.900e+01]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[1.407e+03, 1.500e+01, 5.900e+01]],
#
#        [[2.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[3.390e+02, 0.000e+00, 1.300e+01]],
#
#        [[3.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[3.360e+02, 0.000e+00, 1.300e+01]],
#
#        [[5.900e+01, 0.000e+00, 6.000e+00]],
#
#        [[3.900e+01, 0.000e+00, 6.000e+00]],
#
#        [[3.700e+01, 0.000e+00, 5.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[3.600e+01, 0.000e+00, 5.000e+00]],
#
#        [[2.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[2.000e+01, 0.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[6.000e+00, 0.000e+00, 6.000e+00]],
#
#        [[2.000e+00, 0.000e+00, 6.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 6.000e+00]],
#
#        [[4.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 3.000e+00]],
#
#        [[7.500e+01, 0.000e+00, 3.300e+01]],
#
#        [[7.500e+01, 0.000e+00, 3.200e+01]],
#
#        [[7.200e+01, 0.000e+00, 3.200e+01]],
#
#        [[6.900e+01, 0.000e+00, 3.000e+01]],
#
#        [[3.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[3.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[6.300e+01, 2.190e+02, 9.930e+02]],
#
#        [[6.300e+01, 1.430e+02, 9.810e+02]],
#
#        [[6.300e+01, 3.800e+01, 8.730e+02]],
#
#        [[4.500e+01, 2.600e+01, 2.460e+02]],
#
#        [[5.000e+00, 5.000e+00, 1.340e+02]],
#
#        [[5.000e+00, 4.000e+00, 3.700e+01]],
#
#        [[5.000e+00, 2.000e+00, 3.500e+01]],
#
#        [[4.000e+00, 2.000e+00, 1.300e+01]],
#
#        [[1.000e+00, 2.000e+00, 1.300e+01]],
#
#        [[1.000e+00, 2.000e+00, 6.000e+00]],
#
#        [[0.000e+00, 2.000e+00, 5.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 5.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 3.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 7.000e+00]],
#
#        [[3.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 2.200e+01]],
#
#        [[1.000e+00, 0.000e+00, 7.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 5.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.500e+01]],
#
#        [[0.000e+00, 2.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 9.700e+01]],
#
#        [[0.000e+00, 0.000e+00, 9.300e+01]],
#
#        [[0.000e+00, 1.000e+00, 4.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 4.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[4.000e+01, 2.100e+01, 1.120e+02]],
#
#        [[4.000e+01, 3.000e+00, 4.000e+01]],
#
#        [[4.000e+01, 2.000e+00, 1.700e+01]],
#
#        [[0.000e+00, 1.000e+00, 3.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 3.000e+00]],
#
#        [[4.000e+01, 1.000e+00, 1.400e+01]],
#
#        [[4.000e+01, 0.000e+00, 1.400e+01]],
#
#        [[4.000e+01, 0.000e+00, 1.300e+01]],
#
#        [[9.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[3.100e+01, 0.000e+00, 1.300e+01]],
#
#        [[3.100e+01, 0.000e+00, 1.200e+01]],
#
#        [[2.900e+01, 0.000e+00, 1.200e+01]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[2.800e+01, 0.000e+00, 1.200e+01]],
#
#        [[2.700e+01, 0.000e+00, 1.200e+01]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[2.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 2.300e+01]],
#
#        [[0.000e+00, 1.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.200e+01]],
#
#        [[0.000e+00, 1.800e+01, 7.200e+01]],
#
#        [[0.000e+00, 0.000e+00, 3.900e+01]],
#
#        [[0.000e+00, 1.800e+01, 3.300e+01]],
#
#        [[1.800e+01, 1.200e+01, 6.270e+02]],
#
#        [[1.800e+01, 1.000e+00, 5.200e+01]],
#
#        [[7.000e+00, 0.000e+00, 4.600e+01]],
#
#        [[3.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[3.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[4.000e+00, 0.000e+00, 4.400e+01]],
#
#        [[4.000e+00, 0.000e+00, 1.200e+01]],
#
#        [[0.000e+00, 0.000e+00, 9.000e+00]],
#
#        [[4.000e+00, 0.000e+00, 3.000e+00]],
#
#        [[3.000e+00, 0.000e+00, 3.000e+00]],
#
#        [[1.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 3.200e+01]],
#
#        [[1.100e+01, 1.000e+00, 6.000e+00]],
#
#        [[1.100e+01, 0.000e+00, 4.000e+00]],
#
#        [[1.100e+01, 0.000e+00, 2.000e+00]],
#
#        [[4.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[7.000e+00, 0.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 1.100e+01, 5.750e+02]],
#
#        [[0.000e+00, 9.000e+00, 5.750e+02]],
#
#        [[0.000e+00, 0.000e+00, 3.730e+02]],
#
#        [[0.000e+00, 9.000e+00, 2.020e+02]],
#
#        [[0.000e+00, 2.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 7.000e+00, 2.000e+02]],
#
#        [[0.000e+00, 2.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 1.050e+02, 1.080e+02]],
#
#        [[0.000e+00, 4.000e+00, 1.800e+01]],
#
#        [[0.000e+00, 2.000e+00, 1.600e+01]],
#
#        [[0.000e+00, 1.000e+00, 1.500e+01]],
#
#        [[0.000e+00, 1.000e+00, 3.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.200e+01]],
#
#        [[0.000e+00, 1.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 2.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 2.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 1.010e+02, 9.000e+01]],
#
#        [[0.000e+00, 1.010e+02, 8.800e+01]],
#
#        [[0.000e+00, 1.200e+01, 6.000e+00]],
#
#        [[0.000e+00, 1.200e+01, 5.000e+00]],
#
#        [[0.000e+00, 9.000e+00, 5.000e+00]],
#
#        [[0.000e+00, 3.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 1.000e+00]],
#
#        [[0.000e+00, 8.900e+01, 8.200e+01]],
#
#        [[0.000e+00, 0.000e+00, 5.000e+00]],
#
#        [[0.000e+00, 8.900e+01, 7.700e+01]],
#
#        [[0.000e+00, 8.800e+01, 7.700e+01]],
#
#        [[0.000e+00, 1.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 0.000e+00, 2.000e+00]],
#
#        [[0.000e+00, 7.600e+01, 1.200e+01]],
#
#        [[0.000e+00, 2.000e+00, 0.000e+00]],
#
#        [[0.000e+00, 7.400e+01, 1.200e+01]]])

# %%
predicted = model.predict(X_test)
predicted
# Out:
# array(['HIGH', 'LOW', 'LOW', 'HIGH', 'MEDIUM', 'LOW', 'LOW', 'HIGH',
#        'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'LOW', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'LOW', 'LOW', 'MEDIUM',
#        'LOW', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'LOW', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'LOW', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'LOW', 'MEDIUM', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'LOW', 'LOW', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'LOW', 'LOW', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM',
#        'LOW', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'LOW', 'HIGH', 'MEDIUM',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'LOW', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'LOW', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'LOW', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'LOW', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'LOW', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'LOW', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'LOW', 'MEDIUM', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'LOW', 'HIGH',
#        'HIGH', 'HIGH', 'LOW', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH',
#        'LOW', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'LOW', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'LOW', 'HIGH', 'MEDIUM',
#        'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'LOW', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'MEDIUM', 'MEDIUM', 'LOW', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'HIGH',
#        'HIGH', 'MEDIUM', 'LOW', 'HIGH', 'LOW', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'HIGH', 'MEDIUM', 'HIGH',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'LOW', 'MEDIUM',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'LOW', 'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'LOW', 'MEDIUM', 'LOW', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'LOW', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'HIGH', 'HIGH', 'HIGH',
#        'LOW', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'HIGH', 'HIGH', 'LOW', 'HIGH', 'LOW', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'LOW', 'LOW', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'HIGH', 'MEDIUM',
#        'LOW', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'MEDIUM', 'HIGH',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'LOW', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'MEDIUM', 'LOW', 'MEDIUM', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'MEDIUM', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'LOW',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'MEDIUM', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'MEDIUM', 'HIGH',
#        'HIGH', 'LOW', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'LOW', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'LOW', 'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'MEDIUM', 'LOW', 'HIGH', 'HIGH',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'LOW',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'MEDIUM', 'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'MEDIUM', 'MEDIUM', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM', 'LOW', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'LOW', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'LOW', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'LOW', 'HIGH',
#        'HIGH', 'LOW', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'LOW', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'LOW', 'LOW', 'HIGH',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'MEDIUM', 'MEDIUM', 'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'LOW', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH',
#        'MEDIUM', 'LOW', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'LOW', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'MEDIUM',
#        'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'LOW', 'MEDIUM',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'LOW', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'HIGH', 'MEDIUM',
#        'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'MEDIUM', 'MEDIUM', 'HIGH', 'MEDIUM', 'HIGH', 'LOW', 'HIGH',
#        'HIGH', 'HIGH', 'MEDIUM', 'MEDIUM', 'HIGH', 'HIGH', 'HIGH', 'HIGH',
#        'LOW', 'LOW', 'HIGH', 'HIGH', 'LOW', 'HIGH', 'HIGH'], dtype=object)

# %%
pd.crosstab(y_test, predicted)
# Out:
# col_0          HIGH  LOW  MEDIUM
# %Hiline_level
# HIGH            527    0       5
# LOW               5   49      16
# MEDIUM           33   29     258
