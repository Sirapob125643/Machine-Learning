# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %config InlineBackend.figure_format = 'svg'

# %%
df = pd.read_excel("Final_real_score.xlsx")
df.sample(50)
# Out:
#                   towerid          fl_circuit               flid  \
# 3761                 38-3      115kV_RN-TPNo1     115kV_RN-TPNo1
# 3400                  0-3    500kV_MM3-TTKNo2   500kV_MM3-TTKNo2
# 4183                 45-1    115kV_HY1-STUNo1   115kV_HY1-STUNo1
# 2003                 38-4      115kV_BB-TENo1                  4
# 2818                  771      230kV_BB-NSNo1     230kV_BB-NSNo1
# 563   2023-01-02 00:00:00    115kV_KTL-UB2No2   115kV_KTL-UB2No1
# 1002                246/3     230kV_PL2-NSNo1    230kV_PL2-NSNo1
# 2924                  0-1   115kV_EGAT-CHNNo1  115kV_EGAT-CHNNo1
# 1153                159/3  230kV_PL2-PC-NSNo2    230kV_PL2-NSNo1
# 2958  2023-01-01 00:00:00   115kV_EGAT-SUINo1  115kV_EGAT-SUINo1
# 1163                163/1  230kV_PL2-PC-NSNo2    230kV_PL2-NSNo1
# 1945                123-5     115kV_LP1-TENo1    115kV_LP1-TENo1
# 1762                 58-1      115kV_BB-TENo1                  4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4608 entries, 0 to 4607
# Columns: 142 entries, towerid to %Hiline_level
# dtypes: float64(50), int64(88), object(4)
# memory usage: 5.0+ MB

# %%
df.columns
# Out:
# Index(['towerid', 'fl_circuit', 'flid', 'conductor_visual', ' Wi_con_vir',
#        'conductor_zinc', ' Wi_con_zin', 'conductor_tensile', ' Wi_con_ten',
#        'conductor_ductility',
#        ...
#        '%HImaxCon', '%HImaxCA', '%HImaxINS', '%HImaxSS', '%HImaxFou',
#        '%HImaxLP', '%HImaxTA', '%HImaxROW', '%HIline', '%Hiline_level'],
#       dtype='object', length=142)

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import (
    confusion_matrix,
    plot_confusion_matrix,
    classification_report,
    accuracy_score,
    precision_score,
    recall_score,
    precision_recall_fscore_support,
    f1_score,
)

# %%
df.columns
# Out:
# Index(['towerid', 'fl_circuit', 'flid', 'conductor_visual', ' Wi_con_vir',
#        'conductor_zinc', ' Wi_con_zin', 'conductor_tensile', ' Wi_con_ten',
#        'conductor_ductility',
#        ...
#        '%HImaxCon', '%HImaxCA', '%HImaxINS', '%HImaxSS', '%HImaxFou',
#        '%HImaxLP', '%HImaxTA', '%HImaxROW', '%HIline', '%Hiline_level'],
#       dtype='object', length=142)

# %%
# กำหนด features ที่จะใช้ train โมเดล
feature_cols = ["conductor_visual"," Wi_con_vir","conductor_zinc"," Wi_con_zin","conductor_tensile"," Wi_con_ten","conductor_ductility"," Wi_con_duc","conductor_tensileaac"," Wi_con_aac","Con-Smax","%Hic","conacc_visual","Wi_ca_vir","conacc_spacer","Wi_ca_spac","conacc_clamp","Wi_conacc_clamp","conacc_sc","Wi_conacc_sc","conacc_damping","Wi_conacc_damping","conacc_fating","Wi_conacc_fating","deadend_resistance","Wi_ca_deadr","deadend_thermography","Wi_ca_deadt","clamp_thermography","Wi_ca_clamp","joint_resistance","Wi_ca_jointr","joint_thermography","Wi_ca-jointt","CA-Smax","%Hica","insulator_thermography","Wi_ins_ther","insulator_assester","Wi_ins_asses","insulator_visual","Wi_ins_vir","insulator_fitting","Wi_ins_fit","INS-Smax","%HIins","visual_zinc","Wi_visual_zinc","visual_corrosion","Wi_visual_corrosion","visual_member","Wi_visual_member","visual_nut","Wi_visual_nut","visual_nutstub","Wi_visual_nutstub","visual_no","Wi_visual_no","anchor_color","Wi_anchor_color","anchor_corrosion","Wi_anchor_corrosion","SS-Smax","%HIss","concrete_crack","Wi_concrete_crack","concrete_gliding","Wi_concrete_gliding","concrete_chloride","Wi_concrete_chloride","concrete_mainleg","Wi_concrete_mainleg","concrete_flood","Wi_concrete_flood","concrete_color","Wi_concrete_color","stub_zinc","Wi_stub_zinc","stub_corrosion","Wi_stub_corrosion","found-Smax","%HIfound","protection_opgw","Wi_lp_opgw","protection_zinc","Wi_lp_zinc","protection_tensile","Wi_lp_ten","protection_overhead","Wi_lp_over","protection_marker","Wi_lp_marker","ground_loss","Wi_ground_loss","ground_loose","Wi_ground_loose","ground_oxide","Wi_ground_oxide","Lp-Smax","%Hilp","danger_color","Wi_danger_color","tower_color","Wi_tower_color","tower_broke","Wi_tower_broke","danger_broke","Wi_danger_broke","phase_color","Wi_phase_color","phase_broke","Wi_phase_broke","TA-Smax","%Hitowacc","row_district","Wi_row_district","row_building","Wi_row_building","ROW-Smax","%HIrow","%HItw-con-Wi","%HItw-CA-Wi","%HItw-Ins-Wi","%HItw-SS-Wi","%HItw-Fou-Wi","%HItw-LP-Wi","%HItw-TA-Wi","%HItw-ROW-Wi","%HItower","%HImaxCon","%HImaxCA","%HImaxINS","%HImaxSS","%HImaxFou","%HImaxLP","%HImaxTA","%HImaxROW" ]

# %%
# แบ่งข้อมูลออกเป็น train set และ test set
X_train, X_test, y_train, y_test = train_test_split(df[feature_cols], df["%HIline"], test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# สร้างโมเดล Linear Regression
model = LinearRegression()

# Train โมเดลด้วย X_train และ y_train
model.fit(X_train, y_train)

# แสดงค่า coefficient และ p-value ของแต่ละ feature โดยใช้ statsmodels
X_train = sm.add_constant(X_train) # เพิ่มคอลัมน์ค่าคงที่เข้าไปใน X_train
model_sm = sm.OLS(y_train, X_train).fit()
print(model_sm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                %HIline   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 3.463e+29
# Date:                Sat, 06 May 2023   Prob (F-statistic):               0.00
# Time:                        00:05:58   Log-Likelihood:             1.0171e+05
# No. Observations:                3686   AIC:                        -2.033e+05
# Df Residuals:                    3616   BIC:                        -2.028e+05
# Df Model:                          69
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# conductor_visual        1.554e-14   8.28e-14      0.188      0.851   -1.47e-13    1.78e-13
# ...
